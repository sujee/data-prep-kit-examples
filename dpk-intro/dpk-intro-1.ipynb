# %% [markdown]
# # DPK Demo 1
#
# Showcase DPK's capabilities

# %% [markdown]
# ## Before Running the notebook
#
# Please complete [setting up python dev environment](../setup-python-dev-env.md)

# %% [markdown]
# ## Step-1: Inspect the Data
#
# We will use simple PDFs about Solar system.  The files are here [../data/solar-system/](../data/solar-system/)
#
# ### How to re-generate PDFs?
#
# If you like to play around with various inputs, follow these steps to re-generate PDFs.
#
# First edit the markdown files using any text editor.
#
# Then use [pandoc](https://pandoc.org/) to convert them to pdfs.
#
# ```bash
# pandoc  earth.md  -o earth.pdf
# pandoc  mars.md  -o mars.pdf
# ```

# %% [markdown]
# ## Step-2: Configuration

# %% [markdown]
# ### 2.1 - Basic Config

# %%
import os 

## Configuration
class MyConfig:
    pass 

MY_CONFIG = MyConfig ()

## Input Data - configure this to the folder we want to process
MY_CONFIG.INPUT_DATA_DIR = os.path.join (os.path.abspath (''), '..', 'data', 'solar-system')
MY_CONFIG.OUTPUT_FOLDER = "output"
MY_CONFIG.OUTPUT_FOLDER_FINAL = os.path.join(MY_CONFIG.OUTPUT_FOLDER , "output_final")

## Embedding model
MY_CONFIG.EMBEDDING_MODEL = 'sentence-transformers/all-MiniLM-L6-v2'

## RAY CONFIGURATION
num_cpus_available =  os.cpu_count()
# print (num_cpus_available)
# MY_CONFIG.RAY_NUM_CPUS = num_cpus_available // 2  ## use half the available cores for processing
MY_CONFIG.RAY_NUM_CPUS =  1
# print (MY_CONFIG.RAY_NUM_CPUS)
MY_CONFIG.RAY_MEMORY_GB = 2  # GB
# MY_CONFIG.RAY_RUNTIME_WORKERS = num_cpus_available // 3
MY_CONFIG.RAY_RUNTIME_WORKERS = 2

# %%
## Add parent dir to path
import os,sys 

this_dir = os.path.abspath('')
parent_dir = os.path.dirname(this_dir)
sys.path.append (os.path.abspath (parent_dir))

# %% [markdown]
# ### 2.2 - Setup input/outpur directories

# %%
import os, sys
import shutil

if not os.path.exists(MY_CONFIG.INPUT_DATA_DIR ):
    raise Exception (f"❌ Input folder MY_CONFIG.INPUT_DATA_DIR = '{MY_CONFIG.INPUT_DATA_DIR}' not found")

STAGE = 0

## clear output folder
shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER, ignore_errors=True)
shutil.os.makedirs(MY_CONFIG.OUTPUT_FOLDER, exist_ok=True)

print ("✅ Cleared output directory")
# Out:
# ✅ Cleared output directory

# %% [markdown]
# ## Step-3: pdf2parquet -  Convert data from PDF to Parquet
#
# This step is reading the input folder containing all PDF files and ingest them in a parquet table using the [Docling package](https://github.com/DS4SD/docling).
# The documents are converted into a JSON format which allows to easily chunk it in the later steps.

# %% [markdown]
# ### 3.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE = 1  ## DEBUG

input_folder = MY_CONFIG.INPUT_DATA_DIR
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_parquet_out")

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-1: Processing input='/home/sujee/my-stuff/projects/ai-alliance/data-prep-kit-examples/demo-1/../data/solar-system' --> output='output/01_parquet_out'

# %% [markdown]
# ### 3.2 - Execute

# %%
# %%time 

import ast
import os
import sys

from pdf2parquet_transform import (
    pdf2parquet_contents_type_cli_param,
    pdf2parquet_contents_types,
)
from data_processing_ray.runtime.ray import RayTransformLauncher
from pdf2parquet_transform_python import Pdf2ParquetPythonTransformConfiguration
from pdf2parquet_transform_ray import Pdf2ParquetRayTransformConfiguration

from data_processing.utils import GB, ParamsUtils


# create parameters
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS, "memory": MY_CONFIG.RAY_MEMORY_GB * GB}
ingest_config = {
    pdf2parquet_contents_type_cli_param: pdf2parquet_contents_types.JSON,
}

params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    "data_files_to_use": ast.literal_eval("['.pdf']"),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
}


sys.argv = ParamsUtils.dict_to_req(d=(params | ingest_config))
# create launcher
launcher = RayTransformLauncher(Pdf2ParquetRayTransformConfiguration())
# launcher = PythonTransformLauncher(Pdf2ParquetPythonTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 13:31:54 INFO - Running locally
# 13:31:54 INFO - pdf2parquet parameters are : {'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': False}
# 13:31:54 INFO - data factory data_ is using local data access: input_folder - /home/sujee/my-stuff/projects/ai-alliance/data-prep-kit-examples/demo-1/../data/solar-system output_folder - output/01_parquet_out
# 13:31:54 INFO - data factory data_ max_files -1, n_sample -1
# 13:31:54 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# 13:31:54 INFO - pipeline id pipeline_id
# 13:31:54 INFO - code location None
# 13:31:54 INFO - number of workers 2 worker options {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1}
# 13:31:54 INFO - actor creation delay 0
# 13:31:54 INFO - job details {'job category': 'preprocessing', 'job name': 'pdf2parquet', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 13:31:56,209	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=1230495) 13:32:00 INFO - orchestrator started at 2024-09-06 13:32:00
# (orchestrate pid=1230495) 13:32:00 INFO - Number of files is 2, source profile {'max_file_size': 0.055823326110839844, 'min_file_size': 0.0551910400390625, 'total_file_size': 0.11101436614990234}
# (orchestrate pid=1230495) 13:32:00 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.009171295911074, 'object_store': 6.004585647024214}
# (orchestrate pid=1230495) 13:32:00 INFO - Number of workers - 2 with {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1} each
# (orchestrate pid=1230495) 13:32:00 INFO - Completed 0 files (0.0%)  in 5.884965260823568e-06 min. Waiting for completion
# (RayTransformFileProcessor pid=1231428) 13:32:05 INFO - Initializing models
# Fetching 7 files: 100%|██████████| 7/7 [00:00<00:00, 30743.59it/s]
# (RayTransformFileProcessor pid=1231429) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
# (RayTransformFileProcessor pid=1231429)   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# (orchestrate pid=1230495) 13:32:18 INFO - Completed processing 2 files in 0.2909371534983317 min
# (orchestrate pid=1230495) 13:32:18 INFO - done flushing in 0.0008754730224609375 sec
# (RayTransformFileProcessor pid=1231429) 13:32:05 INFO - Initializing models
# Fetching 7 files: 100%|██████████| 7/7 [00:00<00:00, 43690.67it/s]
# (RayTransformFileProcessor pid=1231428) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
# (RayTransformFileProcessor pid=1231428)   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 13:32:28 INFO - Completed execution in 0.5672494689623515 min, execution result 0
# ✅ Stage:1 completed successfully
# CPU times: user 3.96 s, sys: 1.3 s, total: 5.26 s
# Wall time: 39.2 s

# %% [markdown]
# ### 3.3 - Inspect Generated output
#
# Here we should see one entry per input file processed.

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Output dimensions (rows x columns)= ", output_df.shape)

output_df.head(5)

## To display certain columns
#parquet_df[['column1', 'column2', 'column3']].head(5)
# Out:
# Output dimensions (rows x columns)=  (2, 12)
#     filename                                           contents  num_pages  \
# 0   mars.pdf  {"_name":"","type":"pdf-document","description...          1
# 1  earth.pdf  {"_name":"","type":"pdf-document","description...          1
#
#    num_tables  num_doc_elements                           document_id  ext  \
# 0           0                11  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 1           0                11  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
#
#                                                 hash  size  \
# 0  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 1  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
#
#                 date_acquired  pdf_convert_time source_filename
# 0  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 1  2024-09-06T13:32:18.350258          1.616336       earth.pdf

# %% [markdown]
# ### 3.4 - Understand the output
#
# Here are some interesting attributes to note:
#
# - **filename** : original filename
# - **contents** : text
# - **document_id**: unique id (UUID) assignd to this document
# - **hash** : hash of document
# - **pdf_convert_time** : time to convert this pdf in seconds
#
# Let's inspect the **contents** column.  See how the text is being divided up!

# %%
import pprint
import json

pprint.pprint (json.loads(output_df.iloc[0, ]['contents']))
# json.loads(output_df.iloc[0, ]['contents'])
# Out:
# {'_name': '',
#  'description': {'logs': []},
#  'equations': [],
#  'figures': [],
#  'file-info': {'#-pages': 1,
#                'document-hash': '1a83f43f3a202e3f203c1263e36961ecc45d401aad488f638fc5559a584333b2',
#                'filename': 'mars.pdf',
#                'page-hashes': [{'hash': '551fe7a9bde2a9302f150c0a79a13fcc0868fcf73ac6afb80be645c1174734a0',
#                                 'model': 'default',
#                                 'page': 1}]},
#  'footnotes': [],
#  'main-text': [{'name': 'Section-header',
#                 'prov': [{'bbox': [133.35, 657.11, 169.63, 667.98],
#                           'page': 1,
#                           'span': [0, 4]}],
#                 'text': 'Mars',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.1, 630.68, 210.45, 642.34],
#                           'page': 1,
#                           'span': [0, 12]}],
#                 'text': 'Solar System',
#                 'type': 'subtitle-level-1'},
#                {'name': 'text',
#                 'prov': [{'bbox': [132.85, 590.24, 478.57, 623.03],
#                           'page': 1,
#                           'span': [0, 205]}],
#                 'text': 'Our solar system is a vast and fascinating expanse, '
#                         'comprising eight planets, five dwarf planets, '
#                         'numerous moons, asteroids, comets, and other '
#                         'celestial bodies. At its center lies the star we call '
#                         'the Sun.',
#                 'type': 'paragraph'},
#                {'name': 'text',
#                 'prov': [{'bbox': [133.19, 570.83, 374.24, 581.07],
#                           'page': 1,
#                           'span': [0, 54]}],
#                 'text': 'For more details about the Solar system see Chapter '
#                         '1.',
#                 'type': 'paragraph'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.23, 545.08, 163.69, 554.45],
#                           'page': 1,
#                           'span': [0, 4]}],
#                 'text': 'Mars',
#                 'type': 'subtitle-level-1'},
#                {'name': 'text',
#                 'prov': [{'bbox': [132.87, 500.92, 477.3, 534.56],
#                           'page': 1,
#                           'span': [0, 196]}],
#                 'text': 'Mars, the fourth planet from the Sun, is a cold, '
#                         'desert world with a thin atmosphere composed '
#                         'primarily of carbon dioxide. Its reddish hue comes '
#                         'from iron oxide, or rust, prevalent on its surface.',
#                 'type': 'paragraph'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.2, 484.8, 236.31, 493.07],
#                           'page': 1,
#                           'span': [0, 23]}],
#                 'text': 'Basic facts about Mars:',
#                 'type': 'subtitle-level-1'},
#                {'name': 'text',
#                 'prov': [{'bbox': [147.73, 452.7, 476.98, 474.97],
#                           'page': 1,
#                           'span': [0, 78]}],
#                 'text': '· Distance from the Sun: Average of 228 million '
#                         'kilometers (142 million miles)',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [147.28, 440.75, 430.68, 451.21],
#                           'page': 1,
#                           'span': [0, 64]}],
#                 'text': '· Rotation Period: 24.6 hours (one Martian day - '
#                         'called a "sol")',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [147.35, 429.36, 365.35, 438.84],
#                           'page': 1,
#                           'span': [0, 44]}],
#                 'text': '· Moons: Two small moons, Phobos and Deimos.',
#                 'type': 'paragraph'},
#                {'name': 'Page-footer',
#                 'prov': [{'bbox': [303.3, 89.26, 307.37, 96.52],
#                           'page': 1,
#                           'span': [0, 1]}],
#                 'text': '1',
#                 'type': 'page-footer'}],
#  'page-dimensions': [{'height': 792.0, 'page': 1, 'width': 612.0}],
#  'page-footers': [],
#  'page-headers': [],
#  'tables': [],
#  'type': 'pdf-document'}

# %%
pprint.pprint (json.loads(output_df.iloc[1, ]['contents']))
# Out:
# {'_name': '',
#  'description': {'logs': []},
#  'equations': [],
#  'figures': [],
#  'file-info': {'#-pages': 1,
#                'document-hash': '7401ae81637dbb89e7040dcd5945bbfb75ff8648bb761c69f8a1595e86538748',
#                'filename': 'earth.pdf',
#                'page-hashes': [{'hash': 'ca802e4bd5a3301792808caea2a47db51f0520888875b77fc230c99ee851c19b',
#                                 'model': 'default',
#                                 'page': 1}]},
#  'footnotes': [],
#  'main-text': [{'name': 'Section-header',
#                 'prov': [{'bbox': [133.31, 656.9, 173.65, 667.93],
#                           'page': 1,
#                           'span': [0, 5]}],
#                 'text': 'Earth',
#                 'type': 'subtitle-level-1'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.13, 630.69, 210.44, 642.28],
#                           'page': 1,
#                           'span': [0, 12]}],
#                 'text': 'Solar System',
#                 'type': 'subtitle-level-1'},
#                {'name': 'text',
#                 'prov': [{'bbox': [132.87, 590.26, 478.57, 623.05],
#                           'page': 1,
#                           'span': [0, 205]}],
#                 'text': 'Our solar system is a vast and fascinating expanse, '
#                         'comprising eight planets, five dwarf planets, '
#                         'numerous moons, asteroids, comets, and other '
#                         'celestial bodies. At its center lies the star we call '
#                         'the Sun.',
#                 'type': 'paragraph'},
#                {'name': 'text',
#                 'prov': [{'bbox': [133.21, 570.82, 374.81, 581.08],
#                           'page': 1,
#                           'span': [0, 54]}],
#                 'text': 'For more details about our Solar system see Chapter '
#                         '1.',
#                 'type': 'paragraph'},
#                {'name': 'Section-header',
#                 'prov': [{'bbox': [133.16, 544.91, 167.02, 554.37],
#                           'page': 1,
#                           'span': [0, 5]}],
#                 'text': 'Earth',
#                 'type': 'subtitle-level-1'},
#                {'name': 'text',
#                 'prov': [{'bbox': [132.91, 512.46, 477.41, 534.48],
#                           'page': 1,
#                           'span': [0, 107]}],
#                 'text': "Earth is the third planet from the Sun. It's our home "
#                         'planet. Earth is the only place we know of with life.',
#                 'type': 'paragraph'},
#                {'name': 'Text',
#                 'prov': [{'bbox': [133.3, 496.79, 239.59, 505.07],
#                           'page': 1,
#                           'span': [0, 24]}],
#                 'text': 'Basic facts about Earth:',
#                 'type': 'paragraph'},
#                {'name': 'text',
#                 'prov': [{'bbox': [147.68, 464.66, 477.03, 487.03],
#                           'page': 1,
#                           'span': [0, 79]}],
#                 'text': '· Distance from the Sun: Average of 149.6 million '
#                         'kilometers (93 million miles)',
#                 'type': 'paragraph'},
#                {'name': 'List-item',
#                 'prov': [{'bbox': [147.4, 452.7, 317.19, 463.24],
#                           'page': 1,
#                           'span': [0, 37]}],
#                 'text': '· Rotation Period: 24 hours (one day)',
#                 'type': 'paragraph'},
#                {'name': 'text',
#                 'prov': [{'bbox': [147.33, 440.71, 395.81, 451.2],
#                           'page': 1,
#                           'span': [0, 52]}],
#                 'text': '· Moons: One moon, called Luna or simply "the Moon".',
#                 'type': 'paragraph'},
#                {'name': 'Page-footer',
#                 'prov': [{'bbox': [303.31, 89.24, 307.35, 96.54],
#                           'page': 1,
#                           'span': [0, 1]}],
#                 'text': '1',
#                 'type': 'page-footer'}],
#  'page-dimensions': [{'height': 792.0, 'page': 1, 'width': 612.0}],
#  'page-footers': [],
#  'page-headers': [],
#  'tables': [],
#  'type': 'pdf-document'}

# %% [markdown]
# ##  Step-4: Doc chunks
#
# In the previous step, we have extracted text from oru PDFs.  But we have the content of entire file as 'one row' in our parquet output.
#
# In this step, we are going to split the documents in chunks, according to their layout segmentation.
#
# This transform uses [Quackling](https://github.com/DS4SD/quackling) `HierarchicalChunker`
# to chunk according to the document layout segmentation, i.e. respecting the original document components as paragraphs, tables, enumerations, etc.
# It relies on documents converted with the Docling library in the [pdf2parquet transform](https://github.com/IBM/data-prep-kit/blob/dev/transforms/language/pdf2parquet/python/README.md) using the option `contents_type: "application/json"`,
# which provides the required JSON structure.

# %% [markdown]
# ### 4.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE = 2  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_chunk_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-2: Processing input='output/01_parquet_out' --> output='output/02_chunk_out'

# %% [markdown]
# ### 4.2 - Execute

# %%
# %%time 

from data_processing_ray.runtime.ray import RayTransformLauncher
from doc_chunk_transform_ray import DocChunkRayTransformConfiguration


# Prepare the commandline params
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # doc_chunk arguments
    # ...
}

# Pass the commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# create launcher
launcher = RayTransformLauncher(DocChunkRayTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/sujee/apps/anaconda3/envs/data-prep-
# [nltk_data]     kit-3-py311/lib/python3.11/site-
# [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 13:32:30 INFO - Running locally
# 13:32:30 INFO - doc_chunk parameters are : {'chunking_type': <chunking_types.DL_JSON: 'dl_json'>, 'content_column_name': 'contents', 'output_chunk_column_name': 'contents', 'output_jsonpath_column_name': 'doc_jsonpath', 'output_pageno_column_name': 'page_number', 'output_bbox_column_name': 'bbox'}
# 13:32:30 INFO - data factory data_ is using local data access: input_folder - output/01_parquet_out output_folder - output/02_chunk_out
# 13:32:30 INFO - data factory data_ max_files -1, n_sample -1
# 13:32:30 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 13:32:30 INFO - pipeline id pipeline_id
# 13:32:31 INFO - code location None
# 13:32:31 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 13:32:31 INFO - actor creation delay 0
# 13:32:31 INFO - job details {'job category': 'preprocessing', 'job name': 'doc_chunk', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 13:32:32,848	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=1232636) [nltk_data] Downloading package punkt_tab to
# (orchestrate pid=1232636) [nltk_data]     /home/sujee/apps/anaconda3/envs/data-prep-
# (orchestrate pid=1232636) [nltk_data]     kit-3-py311/lib/python3.11/site-
# (orchestrate pid=1232636) [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# (orchestrate pid=1232636) [nltk_data]   Package punkt_tab is already up-to-date!
# (orchestrate pid=1232636) 13:32:35 INFO - orchestrator started at 2024-09-06 13:32:35
# (orchestrate pid=1232636) 13:32:35 INFO - Number of files is 2, source profile {'max_file_size': 0.020951271057128906, 'min_file_size': 0.02016735076904297, 'total_file_size': 0.041118621826171875}
# (orchestrate pid=1232636) 13:32:35 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.147173310630023, 'object_store': 6.073586653918028}
# (orchestrate pid=1232636) 13:32:35 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=1232636) 13:32:35 INFO - Completed 0 files (0.0%)  in 5.0942103068033855e-06 min. Waiting for completion
# (orchestrate pid=1232636) 13:32:36 INFO - Completed processing 2 files in 0.030245208740234376 min
# (orchestrate pid=1232636) 13:32:36 INFO - done flushing in 0.000823974609375 sec
# 13:32:46 INFO - Completed execution in 0.2655949036280314 min, execution result 0
# (RayTransformFileProcessor pid=1233501) [nltk_data] Downloading package punkt_tab to [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (RayTransformFileProcessor pid=1233501) [nltk_data]     kit-3-py311/lib/python3.11/site- [repeated 4x across cluster]
# (RayTransformFileProcessor pid=1233501) [nltk_data]     packages/llama_index/core/_static/nltk_cache... [repeated 2x across cluster]
# (RayTransformFileProcessor pid=1233501) [nltk_data]   Package punkt_tab is already up-to-date! [repeated 2x across cluster]
# ✅ Stage:2 completed successfully
# CPU times: user 1.37 s, sys: 973 ms, total: 2.35 s
# Wall time: 18.5 s

# %% [markdown]
# ### 4.3 - Inspect Generated output
#
# We would see documents are split into many chunks

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print (f"Files processed : {input_df.shape[0]:,}")
print (f"Chunks created : {output_df.shape[0]:,}")

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Files processed : 2
# Chunks created : 8
# Input data dimensions (rows x columns)=  (2, 12)
# Output data dimensions (rows x columns)=  (8, 15)
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2   mars.pdf          1           0                11
# 3   mars.pdf          1           0                11
# 4  earth.pdf          1           0                11
# 5  earth.pdf          1           0                11
# 6  earth.pdf          1           0                11
# 7  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 1  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 2  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 3  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 4  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 5  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 6  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 7  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
#
#                                                 hash  size  \
# 0  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 1  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 2  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 3  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 4  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 5  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 6  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 7  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 1  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 2  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 3  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 4  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 5  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 6  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 7  2024-09-06T13:32:18.350258          1.616336       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about the Solar...  $.main-text[3]
# 2  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 3  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 4  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 5  Solar System\nFor more details about our Solar...  $.main-text[3]
# 6  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 7  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox
# 0            1  [132.85, 590.24, 478.57, 623.03]
# 1            1  [133.19, 570.83, 374.24, 581.07]
# 2            1   [132.87, 500.92, 477.3, 534.56]
# 3            1   [147.73, 452.7, 476.98, 474.97]
# 4            1  [132.87, 590.26, 478.57, 623.05]
# 5            1  [133.21, 570.82, 374.81, 581.08]
# 6            1  [132.91, 512.46, 477.41, 534.48]
# 7            1  [147.68, 464.66, 477.03, 487.03]

# %% [markdown]
# ### 4.4 - Understanding the Output
#
# Here we see 2 PDF files are split into 6 chunks.  Basically we see the documents are being split along 'natural boundaris' - paragraphs and bullet points
#
# See how **document_id** is carried throughout.  This helps us identify original documents.
#
# Also note **contents** is now plain text (not JSON as before)

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0   mars.pdf  Solar System\nOur solar system is a vast and f...
# 1   mars.pdf  Solar System\nFor more details about the Solar...
# 2   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 3   mars.pdf  Basic facts about Mars:\n· Distance from the S...
# 4  earth.pdf  Solar System\nOur solar system is a vast and f...
# 5  earth.pdf  Solar System\nFor more details about our Solar...
# 6  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 7  earth.pdf  Earth\n· Distance from the Sun: Average of 149...

# %%
for f in output_df['filename'].unique():
    print ('==========' , f, '===========')
    chunks = output_df[output_df['filename'] == f]['contents']
    for idx , chunk in enumerate(chunks):
        print (f'-------Chunk {idx}------\n{chunk}\n-------')
# Out:
# ========== mars.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about the Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Mars
# Mars, the fourth planet from the Sun, is a cold, desert world with a thin atmosphere composed primarily of carbon dioxide. Its reddish hue comes from iron oxide, or rust, prevalent on its surface.
# -------
# -------Chunk 3------
# Basic facts about Mars:
# · Distance from the Sun: Average of 228 million kilometers (142 million miles)
# · Rotation Period: 24.6 hours (one Martian day - called a "sol")
# · Moons: Two small moons, Phobos and Deimos.
# -------
# ========== earth.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about our Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Earth
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
# -------
# -------Chunk 3------
# Earth
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)
# -------

# %% [markdown]
# ## Step-5: Exact Dedup

# %% [markdown]
# ### 5.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE  = 3  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_ededupe_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-3: Processing input='output/02_chunk_out' --> output='output/03_ededupe_out'

# %% [markdown]
# ### 5.2 - Execute

# %%
# %%time

from data_processing_ray.runtime.ray import RayTransformLauncher
from ededup_transform_ray import EdedupRayTransformConfiguration


# Prepare the commandline params
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # ededup parameters
    "ededup_hash_cpu": 0.5,
    "ededup_num_hashes": 2,
    "ededup_doc_column": "contents",
}

# Pass the commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# create launcher
launcher = RayTransformLauncher(EdedupRayTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 13:32:48 INFO - Running locally
# 13:32:48 INFO - exact dedup params are {'doc_column': 'contents', 'hash_cpu': 0.5, 'num_hashes': 2}
# 13:32:48 INFO - data factory data_ is using local data access: input_folder - output/02_chunk_out output_folder - output/03_ededupe_out
# 13:32:48 INFO - data factory data_ max_files -1, n_sample -1
# 13:32:48 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 13:32:48 INFO - pipeline id pipeline_id
# 13:32:48 INFO - code location None
# 13:32:48 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 13:32:48 INFO - actor creation delay 0
# 13:32:48 INFO - job details {'job category': 'preprocessing', 'job name': 'ededup', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 13:32:50,212	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=1234302) 13:32:51 INFO - orchestrator started at 2024-09-06 13:32:51
# (orchestrate pid=1234302) 13:32:51 INFO - Number of files is 2, source profile {'max_file_size': 0.008111000061035156, 'min_file_size': 0.007655143737792969, 'total_file_size': 0.015766143798828125}
# (orchestrate pid=1234302) 13:32:51 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.101344300433993, 'object_store': 6.050672149285674}
# (orchestrate pid=1234302) 13:32:51 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=1234302) 13:32:51 INFO - Completed 0 files (0.0%)  in 5.638599395751953e-06 min. Waiting for completion
# (orchestrate pid=1234302) 13:32:51 INFO - Completed processing 2 files in 0.010762929916381836 min
# (orchestrate pid=1234302) 13:32:51 INFO - done flushing in 0.0009386539459228516 sec
# 13:33:01 INFO - Completed execution in 0.2248418927192688 min, execution result 0
# ✅ Stage:3 completed successfully
# CPU times: user 142 ms, sys: 199 ms, total: 341 ms
# Wall time: 14.9 s

# %% [markdown]
# ### 5.3 - Inspect Generated output

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)
print (f"Input chunks before exact dedupe : {input_df.shape[0]:,}")
print (f"Output chunks after exact dedupe : {output_df.shape[0]:,}")
print ("Duplicate chunks removed :  ", (input_df.shape[0] - output_df.shape[0]))

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (8, 15)
# Output data dimensions (rows x columns)=  (7, 15)
# Input chunks before exact dedupe : 8
# Output chunks after exact dedupe : 7
# Duplicate chunks removed :   1
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2   mars.pdf          1           0                11
# 3   mars.pdf          1           0                11
# 4  earth.pdf          1           0                11
# 5  earth.pdf          1           0                11
# 6  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 1  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 2  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 3  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 4  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 5  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 6  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
#
#                                                 hash  size  \
# 0  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 1  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 2  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 3  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 4  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 5  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 6  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 1  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 2  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 3  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 4  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 5  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 6  2024-09-06T13:32:18.350258          1.616336       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about the Solar...  $.main-text[3]
# 2  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 3  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 4  Solar System\nFor more details about our Solar...  $.main-text[3]
# 5  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 6  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox
# 0            1  [132.85, 590.24, 478.57, 623.03]
# 1            1  [133.19, 570.83, 374.24, 581.07]
# 2            1   [132.87, 500.92, 477.3, 534.56]
# 3            1   [147.73, 452.7, 476.98, 474.97]
# 4            1  [133.21, 570.82, 374.81, 581.08]
# 5            1  [132.91, 512.46, 477.41, 534.48]
# 6            1  [147.68, 464.66, 477.03, 487.03]

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0   mars.pdf  Solar System\nOur solar system is a vast and f...
# 1   mars.pdf  Solar System\nFor more details about the Solar...
# 2   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 3   mars.pdf  Basic facts about Mars:\n· Distance from the S...
# 4  earth.pdf  Solar System\nFor more details about our Solar...
# 5  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 6  earth.pdf  Earth\n· Distance from the Sun: Average of 149...

# %%
for f in output_df['filename'].unique():
    print ('==========' , f, '===========')
    chunks = output_df[output_df['filename'] == f]['contents']
    for idx , chunk in enumerate(chunks):
        print (f'-------Chunk {idx}------\n{chunk}\n-------')
# Out:
# ========== mars.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about the Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Mars
# Mars, the fourth planet from the Sun, is a cold, desert world with a thin atmosphere composed primarily of carbon dioxide. Its reddish hue comes from iron oxide, or rust, prevalent on its surface.
# -------
# -------Chunk 3------
# Basic facts about Mars:
# · Distance from the Sun: Average of 228 million kilometers (142 million miles)
# · Rotation Period: 24.6 hours (one Martian day - called a "sol")
# · Moons: Two small moons, Phobos and Deimos.
# -------
# ========== earth.pdf ===========
# -------Chunk 0------
# Solar System
# For more details about our Solar system see Chapter 1.
# -------
# -------Chunk 1------
# Earth
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
# -------
# -------Chunk 2------
# Earth
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)
# -------

# %% [markdown]
# ### 5.4 - Understanding the output
#
# Remember we had 8 chunks initially.  Now we have 7!  One duplicate chunk is removed.
#
# If you look at the PDF, the following common paragraph in `earth.pdf` and `mars.pdf`  is removed from one of the documents!  Pretty neat, eh!
#
# ```text
# ## Solar System
#
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# ```

# %% [markdown]
# ## Step-6:  DOC ID generation
#
# This transform annotates documents with document "ids". It supports the following transformations of the original data:
#
#  - Adding document hash: this enables the addition of a document hash-based id to the data. The hash is calculated with `hashlib.sha256(doc.encode("utf-8")).hexdigest()`. To enable this annotation, set **hash_column** to the name of the column, where you want to store it.
#  - Adding integer document id: this allows the addition of an integer document id to the data that is unique across all rows in all tables provided to the transform() method. To enable this annotation, set **int_id_column** to the name of the column, where you want to store it.
#
# **This is a pre-requisite for fuzzy dedup** in the pipeline.

# %% [markdown]
# ### 6.1 - Set Input/output Folder

# %%
# Input for this stage is the output of exact dedeup component
# output of this component makes it possible for fdedup component to run on data.

STAGE  += 1
# STAGE  = 4  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_doc_id_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-4: Processing input='output/03_ededupe_out' --> output='output/04_doc_id_out'

# %% [markdown]
# ### 6.2 - Execute

# %%
# %%time 

from data_processing_ray.runtime.ray import RayTransformLauncher
from doc_id_transform_ray import DocIDRayTransformConfiguration
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # doc id configuration
    "doc_id_doc_column": "contents",
    "doc_id_hash_column": "hash_column",
    "doc_id_int_column": "int_id_column",
}
sys.argv = ParamsUtils.dict_to_req(d=params)

# launch

launcher = RayTransformLauncher(DocIDRayTransformConfiguration())

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 13:33:03 INFO - Running locally
# 13:33:03 INFO - Doc id parameters are : {'doc_column': 'contents', 'hash_column': 'hash_column', 'int_column': 'int_id_column'}
# 13:33:03 INFO - data factory data_ is using local data access: input_folder - output/03_ededupe_out output_folder - output/04_doc_id_out
# 13:33:03 INFO - data factory data_ max_files -1, n_sample -1
# 13:33:03 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 13:33:03 INFO - pipeline id pipeline_id
# 13:33:03 INFO - code location None
# 13:33:03 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 13:33:03 INFO - actor creation delay 0
# 13:33:03 INFO - job details {'job category': 'preprocessing', 'job name': 'doc_id', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 13:33:05,177	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=1235983) 13:33:06 INFO - orchestrator started at 2024-09-06 13:33:06
# (orchestrate pid=1235983) 13:33:06 INFO - Number of files is 2, source profile {'max_file_size': 0.008111000061035156, 'min_file_size': 0.007015228271484375, 'total_file_size': 0.015126228332519531}
# (orchestrate pid=1235983) 13:33:06 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.141794587485492, 'object_store': 6.070897292345762}
# (orchestrate pid=1235983) 13:33:06 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=1235983) 13:33:06 INFO - Completed 0 files (0.0%)  in 4.661083221435547e-06 min. Waiting for completion
# (orchestrate pid=1235983) 13:33:06 INFO - Completed processing 2 files in 0.012306106090545655 min
# (orchestrate pid=1235983) 13:33:06 INFO - done flushing in 0.0008840560913085938 sec
# 13:33:16 INFO - Completed execution in 0.22525198856989542 min, execution result 0
# ✅ Stage:4 completed successfully
# CPU times: user 136 ms, sys: 167 ms, total: 303 ms
# Wall time: 14.9 s

# %% [markdown]
# ### 6.3 - Inspect Generated output
#
# You will notice we have two extra columns
#
# - **hash_column**
# - **int_id_column**
#
# But still the same number or rows as before

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (7, 15)
# Output data dimensions (rows x columns)=  (7, 17)
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2   mars.pdf          1           0                11
# 3   mars.pdf          1           0                11
# 4  earth.pdf          1           0                11
# 5  earth.pdf          1           0                11
# 6  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 1  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 2  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 3  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 4  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 5  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 6  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
#
#                                                 hash  size  \
# 0  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 1  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 2  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 3  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 4  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 5  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 6  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 1  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 2  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 3  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 4  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 5  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 6  2024-09-06T13:32:18.350258          1.616336       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about the Solar...  $.main-text[3]
# 2  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 3  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 4  Solar System\nFor more details about our Solar...  $.main-text[3]
# 5  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 6  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox  \
# 0            1  [132.85, 590.24, 478.57, 623.03]
# 1            1  [133.19, 570.83, 374.24, 581.07]
# 2            1   [132.87, 500.92, 477.3, 534.56]
# 3            1   [147.73, 452.7, 476.98, 474.97]
# 4            1  [133.21, 570.82, 374.81, 581.08]
# 5            1  [132.91, 512.46, 477.41, 534.48]
# 6            1  [147.68, 464.66, 477.03, 487.03]
#
#                                          hash_column  int_id_column
# 0  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...              1
# 1  dee4c03474c98efdabbadbcc4ce91138c7820f4ac8ff07...              2
# 2  a31663e06fac41470ecc459f5a58658a3f9997d7801053...              3
# 3  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...              4
# 4  d7be13d7dee96cf2384072d0eb01981e0e75eec2e7bc6d...              5
# 5  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...              6
# 6  0337be5c940b3df316e391ae3dc20379442257498812e4...              7

# %% [markdown]
# ## Step-7: Fuzzy Dedup
#
# Post exact deduplication, fuzzy deduplication is applied with the goal of removing code files that may have **slight variations** and thereby unbiasing
# the data further.
#
# Small variations are quite commonly seen in code data in the form of variations in the values of variables, addittion of logging statements etc.

# %% [markdown]
# ### 7.1 - Set Input/output Folder

# %%
## Input to this component is the output of doc_id generator component. 

STAGE  += 1
# STAGE  = 5  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_fdedupe_out")
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-5: Processing input='output/04_doc_id_out' --> output='output/05_fdedupe_out'

# %% [markdown]
# ### 7.2 - Execute

# %%
# %%time 

import os
import sys

from data_processing.utils import ParamsUtils
from fdedup_transform_ray import FdedupRayTransformConfiguration
from data_processing_ray.runtime.ray import RayTransformLauncher

# create parameters

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
code_location = {"github": "github", "commit_hash": "12345", "path": "path"}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # Orchestration parameters
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # columns used
    "fdedup_doc_column": "contents",
    "fdedup_id_column": "int_id_column",
    "fdedup_cluster_column": "hash_column",
    # infrastructure
    "fdedup_bucket_cpu": 0.5,
    "fdedup_doc_cpu": 0.5,
    "fdedup_mhash_cpu": 0.5,
    "fdedup_num_doc_actors": 2,
    "fdedup_num_bucket_actors": 1,
    "fdedup_num_minhash_actors": 1,
    "fdedup_num_preprocessors": 2,
    # fuzzy parameters
    "fdedup_num_permutations": 64,
    "fdedup_threshold": 0.7, # (default 0.8)
    "fdedup_shingles_size": 5,
    "fdedup_delimiters": " "
}

# Pass commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# launch

launcher = RayTransformLauncher(FdedupRayTransformConfiguration())

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 13:33:18 INFO - Running locally
# 13:33:18 INFO - fuzzy dedup params are {'doc_column': 'contents', 'id_column': 'int_id_column', 'cluster_column': 'hash_column', 'bucket_cpu': 0.5, 'mhash_cpu': 0.5, 'doc_cpu': 0.5, 'num_doc_actors': 2, 'num_minhash_actors': 1, 'num_bucket_actors': 1, 'num_preprocessors': 2, 'num_permutations': 64, 'threshold': 0.7, 'shingles_size': 5, 'delimiters': ' ', 'snapshot_delay': 1, 'use_bucket_snapshot': False, 'use_doc_snapshot': False, 'random_delay_limit': 10, 'worker_options': {'num_cpus': 1}}
# 13:33:18 INFO - data factory data_ is using local data access: input_folder - output/04_doc_id_out output_folder - output/05_fdedupe_out
# 13:33:18 INFO - data factory data_ max_files -1, n_sample -1
# 13:33:18 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 13:33:18 INFO - pipeline id pipeline_id
# 13:33:18 INFO - code location None
# 13:33:18 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 13:33:18 INFO - actor creation delay 0
# 13:33:18 INFO - job details {'job category': 'preprocessing', 'job name': 'fdedup', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 13:33:20,155	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=1237668) 13:33:21 INFO - orchestrator started at 2024-09-06 13:33:21
# (orchestrate pid=1237668) 13:33:21 INFO - Number of files is 2, source profile {'max_file_size': 0.009409904479980469, 'min_file_size': 0.008244514465332031, 'total_file_size': 0.0176544189453125}
# (orchestrate pid=1237668) 13:33:21 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.146500397473574, 'object_store': 6.073250197805464}
# (orchestrate pid=1237668) 13:33:21 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=1237668) 13:33:21 INFO - starting run from the beginning
# (orchestrate pid=1237668) 13:33:21 INFO - continuing from the very beginning
# (orchestrate pid=1237668) 13:33:21 INFO - Fuzzy: num buckets 8, bucket length 8
# (orchestrate pid=1237668) 13:33:21 INFO - created 1 bucket actors
# (orchestrate pid=1237668) 13:33:21 INFO - created 1 minhash actors
# (orchestrate pid=1237668) 13:33:21 INFO - Table preprocessing uses 2 readers
# (orchestrate pid=1237668) 13:33:21 INFO - created 2 table processor actors
# (orchestrate pid=1237668) 13:33:21 INFO - Completed 0 files (0.0%)  in 4.716714223225912e-06 min. Waiting for completion
# (orchestrate pid=1237668) 13:33:28 INFO - Completed processing 2 files in 0.1294346809387207 min
# (orchestrate pid=1237668) 13:33:28 INFO - creating minhash snapshots
# (orchestrate pid=1237668) 13:33:29 INFO - minhash snapshots created
# (orchestrate pid=1237668) 13:33:29 INFO - creating bucket snapshots
# (orchestrate pid=1237668) 13:33:30 INFO - bucket snapshots created
# (orchestrate pid=1237668) 13:33:30 INFO - created 2 document actors
# (orchestrate pid=1237668) 13:33:31 INFO - created 2 bucket processor actors
# (orchestrate pid=1237668) 13:33:31 INFO - created bucket processor invoker
# (orchestrate pid=1237668) 13:33:31 INFO - added invoker to bucket collectors
# (BucketsHash pid=1238494) 13:33:31 INFO - processing buckets 0 long, 53 short
# (BucketsHash pid=1238494) 13:33:31 INFO - Done submitting long buckets
# (BucketsHashProcessorInvoker pid=1239051) 13:33:31 INFO - Waiting bucket processing completion. Submitted requests 1
# (orchestrate pid=1237668) 13:33:31 INFO - Done processing buckets in 0.010995229085286459 min
# (orchestrate pid=1237668) 13:33:31 INFO - creating document snapshots
# (orchestrate pid=1237668) 13:33:33 INFO - document snapshots created
# (orchestrate pid=1237668) 13:33:33 INFO - Completed 0 files (0.0%)  in 9.655952453613281e-06 min. Waiting for completion
# (orchestrate pid=1237668) 13:33:43 INFO - Completed processing 2 files in 0.16260819832483928 min
# (orchestrate pid=1237668) 13:33:43 INFO - done flushing in 0.004254341125488281 sec
# 13:33:53 INFO - Completed execution in 0.5866862297058105 min, execution result 0
# ✅ Stage:5 completed successfully
# CPU times: user 227 ms, sys: 229 ms, total: 456 ms
# Wall time: 36.6 s

# %% [markdown]
# ### 7.3 - Inspect Generated output

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)
print ("Duplicate chunks removed  by fuzzy-dedupe:  ", (input_df.shape[0] - output_df.shape[0]))

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (7, 15)
# Output data dimensions (rows x columns)=  (6, 17)
# Duplicate chunks removed  by fuzzy-dedupe:   1
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2   mars.pdf          1           0                11
# 3   mars.pdf          1           0                11
# 4  earth.pdf          1           0                11
# 5  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 1  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 2  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 3  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 4  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
# 5  3cc17633-f86f-452c-9aad-67bb4a8248eb  pdf
#
#                                                 hash  size  \
# 0  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 1  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 2  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 3  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 4  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
# 5  0260c5d12de8d1ce27a6c096f7983336b1ded574ad3ab8...  2407
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 1  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 2  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 3  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 4  2024-09-06T13:32:18.350258          1.616336       earth.pdf
# 5  2024-09-06T13:32:18.350258          1.616336       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Solar System\nFor more details about the Solar...  $.main-text[3]
# 2  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 3  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 4  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 5  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox  int_id_column  hash_column
# 0            1  [132.85, 590.24, 478.57, 623.03]              1           -1
# 1            1  [133.19, 570.83, 374.24, 581.07]              2            5
# 2            1   [132.87, 500.92, 477.3, 534.56]              3           -1
# 3            1   [147.73, 452.7, 476.98, 474.97]              4           -1
# 4            1  [132.91, 512.46, 477.41, 534.48]              6           -1
# 5            1  [147.68, 464.66, 477.03, 487.03]              7           -1

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0   mars.pdf  Solar System\nOur solar system is a vast and f...
# 1   mars.pdf  Solar System\nFor more details about the Solar...
# 2   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 3   mars.pdf  Basic facts about Mars:\n· Distance from the S...
# 4  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 5  earth.pdf  Earth\n· Distance from the Sun: Average of 149...

# %%
for f in output_df['filename'].unique():
    print ('==========' , f, '===========')
    chunks = output_df[output_df['filename'] == f]['contents']
    for idx , chunk in enumerate(chunks):
        print (f'-------Chunk {idx}------\n{chunk}\n-------')
# Out:
# ========== mars.pdf ===========
# -------Chunk 0------
# Solar System
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# -------
# -------Chunk 1------
# Solar System
# For more details about the Solar system see Chapter 1.
# -------
# -------Chunk 2------
# Mars
# Mars, the fourth planet from the Sun, is a cold, desert world with a thin atmosphere composed primarily of carbon dioxide. Its reddish hue comes from iron oxide, or rust, prevalent on its surface.
# -------
# -------Chunk 3------
# Basic facts about Mars:
# · Distance from the Sun: Average of 228 million kilometers (142 million miles)
# · Rotation Period: 24.6 hours (one Martian day - called a "sol")
# · Moons: Two small moons, Phobos and Deimos.
# -------
# ========== earth.pdf ===========
# -------Chunk 0------
# Earth
# Earth is the third planet from the Sun. It's our home planet. Earth is the only place we know of with life.
# -------
# -------Chunk 1------
# Earth
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)
# -------

# %% [markdown]
# ### 7.4- Understanding the output
#
# So we started with 7 rows and ended up with 6.  Fuzzy dedupe removed the following **very similar** chunk.
#
# These are pretty similar chunks except for the words 'the' and 'our'
#
# **earth.pdf**
#
# `For more details about *our* Solar system see Chapter 1.`
#
# **mars.pdf**
#
# `For more details about *the* Solar system see Chapter 1.`
#
# Pretty neat, eh? 👏
#
# ### Configuring Fuzzy de-dupe
#
# You can tweak fuzzy dedupe by tweaking the following parameters
#
# ```python
# # fuzzy parameters
#     "fdedup_num_permutations": 64,
#     "fdedup_threshold": 0.7, #  (default 0.8)
#     "fdedup_shingles_size": 5,
#     "fdedup_delimiters": " "
# ```
#
# In our case, we set `fdedup_threshold` parameter to 0.7.

# %% [markdown]
# ## Step-8:   Text encoding
#
# Encode text for the vector storage.

# %% [markdown]
# ### 8.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE  = 7 ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_encoder_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-6: Processing input='output/05_fdedupe_out' --> output='output/06_encoder_out'

# %% [markdown]
# ### 8.2 - Execute

# %%
# %%time 

from text_encoder_transform_ray import TextEncoderRayTransformConfiguration

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # text_encoder
    "text_encoder_model_name": MY_CONFIG.EMBEDDING_MODEL,
}

sys.argv = ParamsUtils.dict_to_req(d=params)
# create launcher
launcher = RayTransformLauncher(TextEncoderRayTransformConfiguration())
# Launch the ray actor(s) to process the input

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 13:33:55 INFO - Running locally
# 13:33:55 INFO - text_encoder parameters are : {'content_column_name': 'contents', 'output_embeddings_column_name': 'embeddings', 'model_name': 'sentence-transformers/all-MiniLM-L6-v2'}
# 13:33:55 INFO - data factory data_ is using local data access: input_folder - output/05_fdedupe_out output_folder - output/06_encoder_out
# 13:33:55 INFO - data factory data_ max_files -1, n_sample -1
# 13:33:55 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 13:33:55 INFO - pipeline id pipeline_id
# 13:33:55 INFO - code location None
# 13:33:55 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 13:33:55 INFO - actor creation delay 0
# 13:33:55 INFO - job details {'job category': 'preprocessing', 'job name': 'text_encoder', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 13:33:57,504	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=1240184) 13:34:00 INFO - orchestrator started at 2024-09-06 13:34:00
# (orchestrate pid=1240184) 13:34:00 INFO - Number of files is 2, source profile {'max_file_size': 0.00890350341796875, 'min_file_size': 0.007857322692871094, 'total_file_size': 0.016760826110839844}
# (orchestrate pid=1240184) 13:34:00 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.116310883313417, 'object_store': 6.058155440725386}
# (orchestrate pid=1240184) 13:34:00 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=1240184) 13:34:00 INFO - Completed 0 files (0.0%)  in 8.678436279296875e-06 min. Waiting for completion
# (RayTransformFileProcessor pid=1241071) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# (RayTransformFileProcessor pid=1241071)   warnings.warn(
# (orchestrate pid=1240184) 13:34:05 INFO - Completed processing 2 files in 0.07804395755132039 min
# (orchestrate pid=1240184) 13:34:05 INFO - done flushing in 0.0009279251098632812 sec
# 13:34:15 INFO - Completed execution in 0.32570557594299315 min, execution result 0
# (RayTransformFileProcessor pid=1241070) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# (RayTransformFileProcessor pid=1241070)   warnings.warn(
# ✅ Stage:6 completed successfully
# CPU times: user 587 ms, sys: 250 ms, total: 837 ms
# Wall time: 21.5 s

# %% [markdown]
# ### 8.3 - Inspect Generated output
#
# You will see a column called `embeddings` added at the end.  This the text content converted into vectors or embeddings.  We used the model `sentence-transformers/all-MiniLM-L6-v2`

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.sample(3)
# Out:
# Input data dimensions (rows x columns)=  (6, 17)
# Output data dimensions (rows x columns)=  (6, 18)
#    filename  num_pages  num_tables  num_doc_elements  \
# 1  mars.pdf          1           0                11
# 2  mars.pdf          1           0                11
# 0  mars.pdf          1           0                11
#
#                             document_id  ext  \
# 1  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 2  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
# 0  ca29c82f-4e99-497b-ae77-6a46f6ad1691  pdf
#
#                                                 hash  size  \
# 1  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 2  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
# 0  6dfaeed444efc80bf32e0c67308a57c38cc8d27a6405ec...  2531
#
#                 date_acquired  pdf_convert_time source_filename  \
# 1  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 2  2024-09-06T13:32:18.263250          1.647519        mars.pdf
# 0  2024-09-06T13:32:18.263250          1.647519        mars.pdf
#
#                                             contents    doc_jsonpath  \
# 1  Solar System\nFor more details about the Solar...  $.main-text[3]
# 2  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
#
#    page_number                              bbox  int_id_column  hash_column  \
# 1            1  [133.19, 570.83, 374.24, 581.07]              2            5
# 2            1   [132.87, 500.92, 477.3, 534.56]              3           -1
# 0            1  [132.85, 590.24, 478.57, 623.03]              1           -1
#
#                                           embeddings
# 1  [-0.051861413, 0.0035226392, 0.030617053, 0.04...
# 2  [0.07728298, 0.024971062, -0.04318075, 0.05809...
# 0  [0.0077404897, -0.020559434, 0.026426662, 0.01...

# %% [markdown]
# ## Step-9: Copy output to final output dir

# %%
import shutil

shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER_FINAL, ignore_errors=True)
shutil.copytree(src=output_folder, dst=MY_CONFIG.OUTPUT_FOLDER_FINAL)

print (f"✅ Copied output from '{output_folder}' --> '{MY_CONFIG.OUTPUT_FOLDER_FINAL}'")
# Out:
# ✅ Copied output from 'output/06_encoder_out' --> 'output/output_final'
