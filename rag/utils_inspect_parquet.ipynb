# %% [markdown]
# ## Handy Utils to Inspect a Parquet File

# %%
import pandas as pd
import glob

# we will load all parquet files in this dir
INPUT_DATA_DIR = 'data/granite-docs/output_final'

print ('Loading data from : ', INPUT_DATA_DIR)

# Get a list of all Parquet files in the directory
parquet_files = glob.glob(f'{INPUT_DATA_DIR}/*.parquet')
print ("Number of parquet files to read : ", len(parquet_files))
print ()

# Create an empty list to store the DataFrames
dfs = []

# Loop through each Parquet file and read it into a DataFrame
for file in parquet_files:
    df = pd.read_parquet(file)
    print (f"Read file: '{file}'.  number of rows = {df.shape[0]}")
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
data_df = pd.concat(dfs, ignore_index=True)

print (f"\nTotal number of rows = {data_df.shape[0]}")
# Out:
# Loading data from :  data/granite-docs/output_final
# Number of parquet files to read :  1
#
# Read file: 'data/granite-docs/output_final/Granite_Foundation_Models.parquet'.  number of rows = 216
#
# Total number of rows = 216

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   filename                      216 non-null    object
#  1   num_pages                     216 non-null    int64
#  2   num_tables                    216 non-null    int64
#  3   num_doc_elements              216 non-null    int64
#  4   document_id                   216 non-null    object
#  5   ext                           216 non-null    object
#  6   hash                          216 non-null    object
#  7   size                          216 non-null    int64
#  8   date_acquired                 216 non-null    object
#  9   pdf_convert_time              216 non-null    float64
#  10  source_filename               216 non-null    object
#  11  contents                      216 non-null    object
#  12  doc_jsonpath                  216 non-null    object
#  13  page_number                   216 non-null    int64
#  14  bbox                          216 non-null    object
#  15  int_id_column                 216 non-null    int64
#  16  hash_column                   216 non-null    int64
#  17  docq_total_words              216 non-null    int64
#  18  docq_mean_word_len            216 non-null    float64
#  19  docq_symbol_to_word_ratio     216 non-null    float64
#  20  docq_sentence_count           216 non-null    int64
#  21  docq_lorem_ipsum_ratio        216 non-null    float64
#  22  docq_curly_bracket_ratio      216 non-null    float64
#  23  docq_contain_bad_word         216 non-null    bool
#  24  docq_bullet_point_ratio       216 non-null    float64
#  25  docq_ellipsis_line_ratio      216 non-null    float64
#  26  docq_alphabet_word_ratio      216 non-null    float64
#  27  docq_contain_common_en_words  216 non-null    bool
#  28  embeddings                    216 non-null    object
# dtypes: bool(2), float64(8), int64(9), object(10)
# memory usage: 46.1+ KB

# %%
data_df
# Out:
#                           filename  num_pages  num_tables  num_doc_elements  \
# 0    Granite_Foundation_Models.pdf         20          13               445
# 1    Granite_Foundation_Models.pdf         20          13               445
# 2    Granite_Foundation_Models.pdf         20          13               445
# 3    Granite_Foundation_Models.pdf         20          13               445
# 4    Granite_Foundation_Models.pdf         20          13               445
# ..                             ...        ...         ...               ...
# 211  Granite_Foundation_Models.pdf         20          13               445
# 212  Granite_Foundation_Models.pdf         20          13               445
# 213  Granite_Foundation_Models.pdf         20          13               445
# 214  Granite_Foundation_Models.pdf         20          13               445
# 215  Granite_Foundation_Models.pdf         20          13               445
#
#                               document_id  ext  \
# 0    6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 1    6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 2    6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 3    6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 4    6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# ..                                    ...  ...
# 211  6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 212  6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 213  6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 214  6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
# 215  6b7b64a5-e18c-4dff-8ade-8b5703db74e1  pdf
#
#                                                   hash    size  \
# 0    a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 1    a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 2    a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 3    a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 4    a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# ..                                                 ...     ...
# 211  a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 212  a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 213  a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 214  a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
# 215  a30250ea1dbc6510350d81860e86748e99709566030a50...  357701
#
#                   date_acquired  pdf_convert_time  ...  \
# 0    2024-08-06T21:56:44.353184         70.621034  ...
# 1    2024-08-06T21:56:44.353184         70.621034  ...
# 2    2024-08-06T21:56:44.353184         70.621034  ...
# 3    2024-08-06T21:56:44.353184         70.621034  ...
# 4    2024-08-06T21:56:44.353184         70.621034  ...
# ..                          ...               ...  ...
# 211  2024-08-06T21:56:44.353184         70.621034  ...
# 212  2024-08-06T21:56:44.353184         70.621034  ...
# 213  2024-08-06T21:56:44.353184         70.621034  ...
# 214  2024-08-06T21:56:44.353184         70.621034  ...
# 215  2024-08-06T21:56:44.353184         70.621034  ...
#
#     docq_symbol_to_word_ratio docq_sentence_count docq_lorem_ipsum_ratio  \
# 0                         0.0                   2                    0.0
# 1                         0.0                   1                    0.0
# 2                         0.0                   6                    0.0
# 3                         0.0                  18                    0.0
# 4                         0.0                   4                    0.0
# ..                        ...                 ...                    ...
# 211                       0.0                   2                    0.0
# 212                       0.0                 551                    0.0
# 213                       0.0                   7                    0.0
# 214                       0.0                   3                    0.0
# 215                       0.0                 219                    0.0
#
#      docq_curly_bracket_ratio docq_contain_bad_word  docq_bullet_point_ratio  \
# 0                         0.0                 False                      0.0
# 1                         0.0                 False                      0.0
# 2                         0.0                 False                      0.0
# 3                         0.0                 False                      0.0
# 4                         0.0                 False                      0.0
# ..                        ...                   ...                      ...
# 211                       0.0                 False                      0.0
# 212                       0.0                 False                      0.0
# 213                       0.0                 False                      0.0
# 214                       0.0                 False                      0.0
# 215                       0.0                 False                      0.0
#
#      docq_ellipsis_line_ratio  docq_alphabet_word_ratio  \
# 0                         0.0                  1.000000
# 1                         0.0                  1.000000
# 2                         0.0                  1.000000
# 3                         0.0                  0.970370
# 4                         0.0                  0.981481
# ..                        ...                       ...
# 211                       0.0                  0.931034
# 212                       0.0                  0.597804
# 213                       0.0                  0.982456
# 214                       0.0                  0.920000
# 215                       0.0                  0.614551
#
#      docq_contain_common_en_words  \
# 0                            True
# 1                           False
# 2                            True
# 3                            True
# 4                            True
# ..                            ...
# 211                         False
# 212                         False
# 213                          True
# 214                         False
# 215                         False
#
#                                             embeddings
# 0    [-0.007855933, 0.0186794, 0.04243699, -0.01503...
# 1    [-0.003576741, 0.009818693, 0.03441964, -0.006...
# 2    [-0.022207905, 0.0050711543, 0.022928601, -0.0...
# 3    [0.003014248, -0.0033354084, 0.007243886, -0.0...
# 4    [-0.040923186, -0.045934904, 0.01606972, -0.05...
# ..                                                 ...
# 211  [-0.0014148784, -0.013712707, 0.01091104, -0.0...
# 212  [-0.08738202, -0.048929326, -0.009466442, 0.05...
# 213  [-0.06721652, -0.030914942, -0.018033946, -0.0...
# 214  [-0.018961014, -0.036238465, -0.016582817, -0....
# 215  [-0.091093004, -0.045093857, -0.00561189, 0.00...
#
# [216 rows x 29 columns]
