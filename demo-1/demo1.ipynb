# %% [markdown]
# # DPK Demo 1
#
# Showcase DPK's capabilities

# %% [markdown]
# ## Before Running the notebook
#
# Please complete [setting up python dev environment](../setup-python-dev-env.md)

# %% [markdown]
# ## Step-1: Inspect the Data
#
# We will use simple PDFs about Solar system.  The files are here [../data/solar-system/](../data/solar-system/)
#
# ### How to re-generate PDFs?
#
# If you like to play around with various inputs, follow these steps to re-generate PDFs.
#
# First edit the markdown files using any text editor.
#
# Then use [pandoc](https://pandoc.org/) to convert them to pdfs.
#
# ```bash
# pandoc  earth.md  -o earth.pdf
# pandoc  mars.md  -o mars.pdf
# ```

# %% [markdown]
# ## Step-2: Configuration

# %% [markdown]
# ### 2.1 - Basic Config

# %%
import os 

## Configuration
class MyConfig:
    pass 

MY_CONFIG = MyConfig ()

## Input Data - configure this to the folder we want to process
MY_CONFIG.INPUT_DATA_DIR = os.path.join (os.path.abspath (''), '..', 'data', 'solar-system')
MY_CONFIG.OUTPUT_FOLDER = "output"
MY_CONFIG.OUTPUT_FOLDER_FINAL = os.path.join(MY_CONFIG.OUTPUT_FOLDER , "output_final")

## Embedding model
MY_CONFIG.EMBEDDING_MODEL = 'sentence-transformers/all-MiniLM-L6-v2'

## RAY CONFIGURATION
num_cpus_available =  os.cpu_count()
# print (num_cpus_available)
# MY_CONFIG.RAY_NUM_CPUS = num_cpus_available // 2  ## use half the available cores for processing
MY_CONFIG.RAY_NUM_CPUS =  1
# print (MY_CONFIG.RAY_NUM_CPUS)
MY_CONFIG.RAY_MEMORY_GB = 2  # GB
# MY_CONFIG.RAY_RUNTIME_WORKERS = num_cpus_available // 3
MY_CONFIG.RAY_RUNTIME_WORKERS = 2

# %%
## Add parent dir to path
import os,sys 

this_dir = os.path.abspath('')
parent_dir = os.path.dirname(this_dir)
sys.path.append (os.path.abspath (parent_dir))

# %% [markdown]
# ### 2.2 - Setup input/outpur directories

# %%
import os, sys
import shutil

if not os.path.exists(MY_CONFIG.INPUT_DATA_DIR ):
    raise Exception (f"❌ Input folder MY_CONFIG.INPUT_DATA_DIR = '{MY_CONFIG.INPUT_DATA_DIR}' not found")

STAGE = 0

## clear output folder
shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER, ignore_errors=True)
shutil.os.makedirs(MY_CONFIG.OUTPUT_FOLDER, exist_ok=True)

print ("✅ Cleared output directory")
# Out:
# ✅ Cleared output directory

# %% [markdown]
# ## Step-3: pdf2parquet -  Convert data from PDF to Parquet
#
# This step is reading the input folder containing all PDF files and ingest them in a parquet table using the [Docling package](https://github.com/DS4SD/docling).
# The documents are converted into a JSON format which allows to easily chunk it in the later steps.

# %% [markdown]
# ### 3.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE = 1  ## DEBUG

input_folder = MY_CONFIG.INPUT_DATA_DIR
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_parquet_out")

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-1: Processing input='/home/sujee/my-stuff/projects/ai-alliance/data-prep-kit-examples/demo-1/../data/solar-system' --> output='output/01_parquet_out'

# %% [markdown]
# ### 3.2 - Execute

# %%
# %%time 

import ast
import os
import sys

from pdf2parquet_transform import (
    pdf2parquet_contents_type_cli_param,
    pdf2parquet_contents_types,
)
from data_processing_ray.runtime.ray import RayTransformLauncher
from pdf2parquet_transform_python import Pdf2ParquetPythonTransformConfiguration
from pdf2parquet_transform_ray import Pdf2ParquetRayTransformConfiguration

from data_processing.utils import GB, ParamsUtils


# create parameters
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS, "memory": MY_CONFIG.RAY_MEMORY_GB * GB}
ingest_config = {
    pdf2parquet_contents_type_cli_param: pdf2parquet_contents_types.JSON,
}

params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    "data_files_to_use": ast.literal_eval("['.pdf']"),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
}


sys.argv = ParamsUtils.dict_to_req(d=(params | ingest_config))
# create launcher
launcher = RayTransformLauncher(Pdf2ParquetRayTransformConfiguration())
# launcher = PythonTransformLauncher(Pdf2ParquetPythonTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 01:45:39 INFO - Running locally
# 01:45:39 INFO - pdf2parquet parameters are : {'artifacts_path': None, 'contents_type': <pdf2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': False}
# 01:45:39 INFO - data factory data_ is using local data access: input_folder - /home/sujee/my-stuff/projects/ai-alliance/data-prep-kit-examples/demo-1/../data/solar-system output_folder - output/01_parquet_out
# 01:45:39 INFO - data factory data_ max_files -1, n_sample -1
# 01:45:39 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# 01:45:39 INFO - pipeline id pipeline_id
# 01:45:39 INFO - code location None
# 01:45:39 INFO - number of workers 2 worker options {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1}
# 01:45:39 INFO - actor creation delay 0
# 01:45:39 INFO - job details {'job category': 'preprocessing', 'job name': 'pdf2parquet', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 01:45:41,513	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=252722) 01:45:46 INFO - orchestrator started at 2024-09-06 01:45:46
# (orchestrate pid=252722) 01:45:46 INFO - Number of files is 2, source profile {'max_file_size': 0.055919647216796875, 'min_file_size': 0.055187225341796875, 'total_file_size': 0.11110687255859375}
# (orchestrate pid=252722) 01:45:46 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.820719910785556, 'object_store': 6.410359954461455}
# (orchestrate pid=252722) 01:45:46 INFO - Number of workers - 2 with {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1} each
# (orchestrate pid=252722) 01:45:46 INFO - Completed 0 files (0.0%)  in 4.907449086507161e-06 min. Waiting for completion
# (RayTransformFileProcessor pid=253632) 01:45:50 INFO - Initializing models
# Fetching 7 files: 100%|██████████| 7/7 [00:00<00:00, 166818.91it/s]
# (RayTransformFileProcessor pid=253632) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
# (RayTransformFileProcessor pid=253632)   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# (orchestrate pid=252722) 01:46:03 INFO - Completed processing 2 files in 0.2885281244913737 min
# (orchestrate pid=252722) 01:46:03 INFO - done flushing in 0.0008900165557861328 sec
# (RayTransformFileProcessor pid=253631) 01:45:50 INFO - Initializing models
# Fetching 7 files: 100%|██████████| 7/7 [00:00<00:00, 143922.20it/s]
# (RayTransformFileProcessor pid=253631) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
# (RayTransformFileProcessor pid=253631)   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# 01:46:13 INFO - Completed execution in 0.5638823429743449 min, execution result 0
# ✅ Stage:1 completed successfully
# CPU times: user 3.95 s, sys: 1.3 s, total: 5.25 s
# Wall time: 39 s

# %% [markdown]
# ### 3.3 - Inspect Generated output
#
# Here we should see one entry per input file processed.

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Output dimensions (rows x columns)= ", output_df.shape)

output_df.head(5)

## To display certain columns
#parquet_df[['column1', 'column2', 'column3']].head(5)
# Out:
# Output dimensions (rows x columns)=  (2, 12)
#     filename                                           contents  num_pages  \
# 0   mars.pdf  {"_name":"","type":"pdf-document","description...          1
# 1  earth.pdf  {"_name":"","type":"pdf-document","description...          1
#
#    num_tables  num_doc_elements                           document_id  ext  \
# 0           0                11  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 1           0                11  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
#
#                                                 hash  size  \
# 0  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 1  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
#
#                 date_acquired  pdf_convert_time source_filename
# 0  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 1  2024-09-06T01:46:03.087877          1.674357       earth.pdf

# %% [markdown]
# ### 3.4 - Understand the output
#
# Here are some interesting attributes to note:
#
# - **filename** : original filename
# - **contents** : text
# - **document_id**: unique id (UUID) assignd to this document
# - **hash** : hash of document (TODO: what kind of hash?)
# - **pdf_convert_time** : time to convert this pdf in seconds
#
# Let's inspect the **contents** column.  See how the text is being divided up!

# %%
import pprint
import json

pprint.pprint (json.loads(output_df.iloc[0, ]['contents']), indent=4)
# Out:
# {   '_name': '',
#     'description': {'logs': []},
#     'equations': [],
#     'figures': [],
#     'file-info': {   '#-pages': 1,
#                      'document-hash': '0ff74fc417f3c08a05fa8b4d631b898b32a777c01c109391405ee5324d54b9cb',
#                      'filename': 'mars.pdf',
#                      'page-hashes': [   {   'hash': '5ae83e3b85582da642213d2e8a41b382a8a2c24c88f2b2a76a96ba0725493ecf',
#                                             'model': 'default',
#                                             'page': 1}]},
#     'footnotes': [],
#     'main-text': [   {   'name': 'Section-header',
#                          'prov': [   {   'bbox': [   133.35,
#                                                      657.12,
#                                                      169.62,
#                                                      667.98],
#                                          'page': 1,
#                                          'span': [0, 4]}],
#                          'text': 'Mars',
#                          'type': 'subtitle-level-1'},
#                      {   'name': 'Section-header',
#                          'prov': [   {   'bbox': [133.1, 630.7, 210.43, 642.33],
#                                          'page': 1,
#                                          'span': [0, 12]}],
#                          'text': 'Solar System',
#                          'type': 'subtitle-level-1'},
#                      {   'name': 'text',
#                          'prov': [   {   'bbox': [   132.82,
#                                                      590.31,
#                                                      478.56,
#                                                      623.02],
#                                          'page': 1,
#                                          'span': [0, 205]}],
#                          'text': 'Our solar system is a vast and fascinating '
#                                  'expanse, comprising eight planets, five '
#                                  'dwarf planets, numerous moons, asteroids, '
#                                  'comets, and other celestial bodies. At its '
#                                  'center lies the star we call the Sun.',
#                          'type': 'paragraph'},
#                      {   'name': 'text',
#                          'prov': [   {   'bbox': [   133.23,
#                                                      570.71,
#                                                      270.16,
#                                                      581.03],
#                                          'page': 1,
#                                          'span': [0, 31]}],
#                          'text': 'For more details see Chapter 1.',
#                          'type': 'paragraph'},
#                      {   'name': 'Section-header',
#                          'prov': [   {   'bbox': [   133.23,
#                                                      545.09,
#                                                      163.7,
#                                                      554.44],
#                                          'page': 1,
#                                          'span': [0, 4]}],
#                          'text': 'Mars',
#                          'type': 'subtitle-level-1'},
#                      {   'name': 'text',
#                          'prov': [   {   'bbox': [   132.86,
#                                                      500.93,
#                                                      477.3,
#                                                      534.53],
#                                          'page': 1,
#                                          'span': [0, 196]}],
#                          'text': 'Mars, the fourth planet from the Sun, is a '
#                                  'cold, desert world with a thin atmosphere '
#                                  'composed primarily of carbon dioxide. Its '
#                                  'reddish hue comes from iron oxide, or rust, '
#                                  'prevalent on its surface.',
#                          'type': 'paragraph'},
#                      {   'name': 'Section-header',
#                          'prov': [   {   'bbox': [133.2, 484.8, 236.3, 493.08],
#                                          'page': 1,
#                                          'span': [0, 23]}],
#                          'text': 'Basic facts about Mars:',
#                          'type': 'subtitle-level-1'},
#                      {   'name': 'text',
#                          'prov': [   {   'bbox': [   147.72,
#                                                      452.7,
#                                                      476.98,
#                                                      474.97],
#                                          'page': 1,
#                                          'span': [0, 78]}],
#                          'text': '· Distance from the Sun: Average of 228 '
#                                  'million kilometers (142 million miles)',
#                          'type': 'paragraph'},
#                      {   'name': 'List-item',
#                          'prov': [   {   'bbox': [   147.28,
#                                                      440.75,
#                                                      430.67,
#                                                      451.21],
#                                          'page': 1,
#                                          'span': [0, 64]}],
#                          'text': '· Rotation Period: 24.6 hours (one Martian '
#                                  'day - called a "sol")',
#                          'type': 'paragraph'},
#                      {   'name': 'List-item',
#                          'prov': [   {   'bbox': [   147.35,
#                                                      429.36,
#                                                      365.35,
#                                                      438.83],
#                                          'page': 1,
#                                          'span': [0, 44]}],
#                          'text': '· Moons: Two small moons, Phobos and Deimos.',
#                          'type': 'paragraph'},
#                      {   'name': 'Page-footer',
#                          'prov': [   {   'bbox': [303.3, 89.26, 307.37, 96.52],
#                                          'page': 1,
#                                          'span': [0, 1]}],
#                          'text': '1',
#                          'type': 'page-footer'}],
#     'page-dimensions': [{'height': 792.0, 'page': 1, 'width': 612.0}],
#     'page-footers': [],
#     'page-headers': [],
#     'tables': [],
#     'type': 'pdf-document'}

# %% [markdown]
# ##  Step-4: Doc chunks
#
# In the previous step, we have extracted text from oru PDFs.  But we have the content of entire file as 'one row' in our parquet output.
#
# In this step, we are going to split the documents in chunks, according to their layout segmentation.
#
# This transform uses [Quackling](https://github.com/DS4SD/quackling) `HierarchicalChunker`
# to chunk according to the document layout segmentation, i.e. respecting the original document components as paragraphs, tables, enumerations, etc.
# It relies on documents converted with the Docling library in the [pdf2parquet transform](https://github.com/IBM/data-prep-kit/blob/dev/transforms/language/pdf2parquet/python/README.md) using the option `contents_type: "application/json"`,
# which provides the required JSON structure.

# %% [markdown]
# ### 4.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE = 2  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_chunk_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-2: Processing input='output/01_parquet_out' --> output='output/02_chunk_out'

# %% [markdown]
# ### 4.2 - Execute

# %%
# %%time 

from data_processing_ray.runtime.ray import RayTransformLauncher
from doc_chunk_transform_ray import DocChunkRayTransformConfiguration


# Prepare the commandline params
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # doc_chunk arguments
    # ...
}

# Pass the commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# create launcher
launcher = RayTransformLauncher(DocChunkRayTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/sujee/apps/anaconda3/envs/data-prep-
# [nltk_data]     kit-3-py311/lib/python3.11/site-
# [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 01:46:15 INFO - Running locally
# 01:46:15 INFO - doc_chunk parameters are : {'chunking_type': <chunking_types.DL_JSON: 'dl_json'>, 'content_column_name': 'contents', 'output_chunk_column_name': 'contents', 'output_jsonpath_column_name': 'doc_jsonpath', 'output_pageno_column_name': 'page_number', 'output_bbox_column_name': 'bbox'}
# 01:46:15 INFO - data factory data_ is using local data access: input_folder - output/01_parquet_out output_folder - output/02_chunk_out
# 01:46:15 INFO - data factory data_ max_files -1, n_sample -1
# 01:46:15 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 01:46:15 INFO - pipeline id pipeline_id
# 01:46:15 INFO - code location None
# 01:46:15 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 01:46:15 INFO - actor creation delay 0
# 01:46:15 INFO - job details {'job category': 'preprocessing', 'job name': 'doc_chunk', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 01:46:17,745	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=254824) [nltk_data] Downloading package punkt_tab to
# (orchestrate pid=254824) [nltk_data]     /home/sujee/apps/anaconda3/envs/data-prep-
# (orchestrate pid=254824) [nltk_data]     kit-3-py311/lib/python3.11/site-
# (orchestrate pid=254824) [nltk_data]     packages/llama_index/core/_static/nltk_cache...
# (orchestrate pid=254824) [nltk_data]   Package punkt_tab is already up-to-date!
# (orchestrate pid=254824) 01:46:19 INFO - orchestrator started at 2024-09-06 01:46:19
# (orchestrate pid=254824) 01:46:19 INFO - Number of files is 2, source profile {'max_file_size': 0.020799636840820312, 'min_file_size': 0.020008087158203125, 'total_file_size': 0.04080772399902344}
# (orchestrate pid=254824) 01:46:19 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.821333314292133, 'object_store': 6.410666655749083}
# (orchestrate pid=254824) 01:46:19 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=254824) 01:46:19 INFO - Completed 0 files (0.0%)  in 4.839897155761719e-06 min. Waiting for completion
# (orchestrate pid=254824) 01:46:21 INFO - Completed processing 2 files in 0.03090968132019043 min
# (orchestrate pid=254824) 01:46:21 INFO - done flushing in 0.0008466243743896484 sec
# 01:46:31 INFO - Completed execution in 0.26524134874343874 min, execution result 0
# (RayTransformFileProcessor pid=255691) [nltk_data] Downloading package punkt_tab to [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (RayTransformFileProcessor pid=255691) [nltk_data]     kit-3-py311/lib/python3.11/site- [repeated 4x across cluster]
# (RayTransformFileProcessor pid=255691) [nltk_data]     packages/llama_index/core/_static/nltk_cache... [repeated 2x across cluster]
# (RayTransformFileProcessor pid=255691) [nltk_data]   Package punkt_tab is already up-to-date! [repeated 2x across cluster]
# ✅ Stage:2 completed successfully
# CPU times: user 1.35 s, sys: 935 ms, total: 2.28 s
# Wall time: 18.2 s

# %% [markdown]
# ### 4.3 - Inspect Generated output
#
# We would see documents are split into many chunks

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print (f"Files processed : {input_df.shape[0]:,}")
print (f"Chunks created : {output_df.shape[0]:,}")

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Files processed : 2
# Chunks created : 6
# Input data dimensions (rows x columns)=  (2, 12)
# Output data dimensions (rows x columns)=  (6, 15)
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2   mars.pdf          1           0                11
# 3  earth.pdf          1           0                11
# 4  earth.pdf          1           0                11
# 5  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 1  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 2  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 3  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 4  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 5  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
#
#                                                 hash  size  \
# 0  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 1  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 2  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 3  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 4  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 5  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 1  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 2  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 3  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 4  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 5  2024-09-06T01:46:03.087877          1.674357       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 1  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 2  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 3  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 4  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 5  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox
# 0            1  [132.82, 590.31, 478.56, 623.02]
# 1            1   [132.86, 500.93, 477.3, 534.53]
# 2            1   [147.72, 452.7, 476.98, 474.97]
# 3            1  [132.82, 590.31, 478.58, 623.05]
# 4            1  [132.89, 512.46, 477.42, 534.47]
# 5            1  [147.68, 464.66, 477.03, 487.02]

# %% [markdown]
# ### 4.4 - Understanding the Output
#
# Here we see 2 PDF files are split into 6 chunks.  Basically we see the documents are being split along 'natural boundaris' - paragraphs and bullet points
#
# See how **document_id** is carried throughout.  This helps us identify original documents.
#
# Also note **contents** is now plain text (not JSON as before)

# %%
output_df[['filename', 'contents']]
# Out:
#     filename                                           contents
# 0   mars.pdf  Solar System\nOur solar system is a vast and f...
# 1   mars.pdf  Mars\nMars, the fourth planet from the Sun, is...
# 2   mars.pdf  Basic facts about Mars:\n· Distance from the S...
# 3  earth.pdf  Solar System\nOur solar system is a vast and f...
# 4  earth.pdf  Earth\nEarth is the third planet from the Sun....
# 5  earth.pdf  Earth\n· Distance from the Sun: Average of 149...

# %%
print (output_df.iloc[-1]['contents'])
# Out:
# Earth
# · Distance from the Sun: Average of 149.6 million kilometers (93 million miles)
# · Rotation Period: 24 hours (one day)

# %% [markdown]
# ## Step-5: Exact Dedup

# %% [markdown]
# ### 5.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE  = 3  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_ededupe_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-3: Processing input='output/02_chunk_out' --> output='output/03_ededupe_out'

# %% [markdown]
# ### 5.2 - Execute

# %%
# %%time

from data_processing_ray.runtime.ray import RayTransformLauncher
from ededup_transform_ray import EdedupRayTransformConfiguration


# Prepare the commandline params
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # ededup parameters
    "ededup_hash_cpu": 0.5,
    "ededup_num_hashes": 2,
    "ededup_doc_column": "contents",
}

# Pass the commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# create launcher
launcher = RayTransformLauncher(EdedupRayTransformConfiguration())
# launch
return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 01:46:33 INFO - Running locally
# 01:46:33 INFO - exact dedup params are {'doc_column': 'contents', 'hash_cpu': 0.5, 'num_hashes': 2}
# 01:46:33 INFO - data factory data_ is using local data access: input_folder - output/02_chunk_out output_folder - output/03_ededupe_out
# 01:46:33 INFO - data factory data_ max_files -1, n_sample -1
# 01:46:33 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 01:46:33 INFO - pipeline id pipeline_id
# 01:46:33 INFO - code location None
# 01:46:33 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 01:46:33 INFO - actor creation delay 0
# 01:46:33 INFO - job details {'job category': 'preprocessing', 'job name': 'ededup', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 01:46:34,977	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=256451) 01:46:35 INFO - orchestrator started at 2024-09-06 01:46:35
# (orchestrate pid=256451) 01:46:35 INFO - Number of files is 2, source profile {'max_file_size': 0.008029937744140625, 'min_file_size': 0.007578849792480469, 'total_file_size': 0.015608787536621094}
# (orchestrate pid=256451) 01:46:35 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.81810836866498, 'object_store': 6.409054183401167}
# (orchestrate pid=256451) 01:46:35 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=256451) 01:46:35 INFO - Completed 0 files (0.0%)  in 5.670388539632162e-06 min. Waiting for completion
# (orchestrate pid=256451) 01:46:36 INFO - Completed processing 2 files in 0.01104350487391154 min
# (orchestrate pid=256451) 01:46:36 INFO - done flushing in 0.0009675025939941406 sec
# 01:46:46 INFO - Completed execution in 0.22442639668782552 min, execution result 0
# ✅ Stage:3 completed successfully
# CPU times: user 96.4 ms, sys: 148 ms, total: 244 ms
# Wall time: 14.9 s

# %% [markdown]
# ### 5.3 - Inspect Generated output

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)
print (f"Input chunks before exact dedupe : {input_df.shape[0]:,}")
print (f"Output chunks after exact dedupe : {output_df.shape[0]:,}")
print ("Duplicate chunks removed :  ", (input_df.shape[0] - output_df.shape[0]))

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (6, 15)
# Output data dimensions (rows x columns)=  (5, 15)
# Input chunks before exact dedupe : 6
# Output chunks after exact dedupe : 5
# Duplicate chunks removed :   1
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2  earth.pdf          1           0                11
# 3  earth.pdf          1           0                11
# 4  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 1  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 2  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 3  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 4  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
#
#                                                 hash  size  \
# 0  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 1  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 2  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 3  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 4  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 1  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 2  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 3  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 4  2024-09-06T01:46:03.087877          1.674357       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 1  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 2  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 3  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 4  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox
# 0            1   [132.86, 500.93, 477.3, 534.53]
# 1            1   [147.72, 452.7, 476.98, 474.97]
# 2            1  [132.82, 590.31, 478.58, 623.05]
# 3            1  [132.89, 512.46, 477.42, 534.47]
# 4            1  [147.68, 464.66, 477.03, 487.02]

# %% [markdown]
# ### 5.4 - Understanding the output
#
# Remember we had 6 chunks initially.  Now we have 5!  One duplicate chunk is removed.
#
# If you look at the PDF, the following common paragraph in `earth.pdf` and `mars.pdf`  is removed from one of the documents!  Pretty neat, eh!
#
# ```text
# ## Solar System
#
# Our solar system is a vast and fascinating expanse, comprising eight planets, five dwarf planets, numerous moons, asteroids, comets, and other celestial bodies. At its center lies the star we call the Sun.
# ```

# %% [markdown]
# ## Step-6:  DOC ID generation
#
# This transform annotates documents with document "ids". It supports the following transformations of the original data:
#
#  - Adding document hash: this enables the addition of a document hash-based id to the data. The hash is calculated with `hashlib.sha256(doc.encode("utf-8")).hexdigest()`. To enable this annotation, set **hash_column** to the name of the column, where you want to store it.
#  - Adding integer document id: this allows the addition of an integer document id to the data that is unique across all rows in all tables provided to the transform() method. To enable this annotation, set **int_id_column** to the name of the column, where you want to store it.
#
# **This is a pre-requisite for fuzzy dedup** in the pipeline.

# %% [markdown]
# ### 6.1 - Set Input/output Folder

# %%
# Input for this stage is the output of exact dedeup component
# output of this component makes it possible for fdedup component to run on data.

STAGE  += 1
# STAGE  = 4  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_doc_id_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-4: Processing input='output/03_ededupe_out' --> output='output/04_doc_id_out'

# %% [markdown]
# ### 6.2 - Execute

# %%
# %%time 

from data_processing_ray.runtime.ray import RayTransformLauncher
from doc_id_transform_ray import DocIDRayTransformConfiguration
local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # doc id configuration
    "doc_id_doc_column": "contents",
    "doc_id_hash_column": "hash_column",
    "doc_id_int_column": "int_id_column",
}
sys.argv = ParamsUtils.dict_to_req(d=params)

# launch

launcher = RayTransformLauncher(DocIDRayTransformConfiguration())

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 01:46:48 INFO - Running locally
# 01:46:48 INFO - Doc id parameters are : {'doc_column': 'contents', 'hash_column': 'hash_column', 'int_column': 'int_id_column'}
# 01:46:48 INFO - data factory data_ is using local data access: input_folder - output/03_ededupe_out output_folder - output/04_doc_id_out
# 01:46:48 INFO - data factory data_ max_files -1, n_sample -1
# 01:46:48 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 01:46:48 INFO - pipeline id pipeline_id
# 01:46:48 INFO - code location None
# 01:46:48 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 01:46:48 INFO - actor creation delay 0
# 01:46:48 INFO - job details {'job category': 'preprocessing', 'job name': 'doc_id', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 01:46:50,050	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=258443) 01:46:51 INFO - orchestrator started at 2024-09-06 01:46:51
# (orchestrate pid=258443) 01:46:51 INFO - Number of files is 2, source profile {'max_file_size': 0.007781982421875, 'min_file_size': 0.007578849792480469, 'total_file_size': 0.015360832214355469}
# (orchestrate pid=258443) 01:46:51 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.57746429555118, 'object_store': 6.288732146844268}
# (orchestrate pid=258443) 01:46:51 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=258443) 01:46:51 INFO - Completed 0 files (0.0%)  in 5.241235097249349e-06 min. Waiting for completion
# (orchestrate pid=258443) 01:46:51 INFO - Completed processing 2 files in 0.012762896219889323 min
# (orchestrate pid=258443) 01:46:51 INFO - done flushing in 0.0009598731994628906 sec
# 01:47:01 INFO - Completed execution in 0.22972962458928425 min, execution result 0
# ✅ Stage:4 completed successfully
# CPU times: user 107 ms, sys: 130 ms, total: 238 ms
# Wall time: 15.3 s

# %% [markdown]
# ### 6.3 - Inspect Generated output
#
# You will notice we have two extra columns
#
# - **hash_column**
# - **int_id_column**
#
# But still the same number or rows as before

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (5, 15)
# Output data dimensions (rows x columns)=  (5, 17)
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2  earth.pdf          1           0                11
# 3  earth.pdf          1           0                11
# 4  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 1  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 2  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 3  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 4  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
#
#                                                 hash  size  \
# 0  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 1  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 2  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 3  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 4  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 1  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 2  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 3  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 4  2024-09-06T01:46:03.087877          1.674357       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 1  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 2  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 3  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 4  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox  \
# 0            1   [132.86, 500.93, 477.3, 534.53]
# 1            1   [147.72, 452.7, 476.98, 474.97]
# 2            1  [132.82, 590.31, 478.58, 623.05]
# 3            1  [132.89, 512.46, 477.42, 534.47]
# 4            1  [147.68, 464.66, 477.03, 487.02]
#
#                                          hash_column  int_id_column
# 0  a31663e06fac41470ecc459f5a58658a3f9997d7801053...              4
# 1  7ff317954ec5f3b15607c053c30c2b0db0f6b64cc3295a...              5
# 2  44c6e373258c7cdc03f75a8e96a9b160f9aa4e4baf5674...              1
# 3  7c4a750e2215f231803a6f8078bde1e9699034fb033dd3...              2
# 4  0337be5c940b3df316e391ae3dc20379442257498812e4...              3

# %% [markdown]
# ## Step-7: Fuzzy Dedup
#
# Post exact deduplication, fuzzy deduplication is applied with the goal of removing code files that may have **slight variations** and thereby unbiasing
# the data further.
#
# Small variations are quite commonly seen in code data in the form of variations in the values of variables, addittion of logging statements etc.

# %% [markdown]
# ### 7.1 - Set Input/output Folder

# %%
## Input to this component is the output of doc_id generator component. 

STAGE  += 1
# STAGE  = 5  ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_fdedupe_out")
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-5: Processing input='output/04_doc_id_out' --> output='output/05_fdedupe_out'

# %% [markdown]
# ### 7.2 - Execute

# %%
# %%time 

import os
import sys

from data_processing.utils import ParamsUtils
from fdedup_transform_ray import FdedupRayTransformConfiguration
from data_processing_ray.runtime.ray import RayTransformLauncher

# create parameters

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
code_location = {"github": "github", "commit_hash": "12345", "path": "path"}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # Orchestration parameters
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # columns used
    "fdedup_doc_column": "contents",
    "fdedup_id_column": "int_id_column",
    "fdedup_cluster_column": "hash_column",
    # infrastructure
    "fdedup_bucket_cpu": 0.5,
    "fdedup_doc_cpu": 0.5,
    "fdedup_mhash_cpu": 0.5,
    "fdedup_num_doc_actors": 2,
    "fdedup_num_bucket_actors": 1,
    "fdedup_num_minhash_actors": 1,
    "fdedup_num_preprocessors": 2,
    # fuzzy parameters
    "fdedup_num_permutations": 64,
    "fdedup_threshold": 0.8,
    "fdedup_shingles_size": 5,
    "fdedup_delimiters": " "
}

# Pass commandline params
sys.argv = ParamsUtils.dict_to_req(d=params)

# launch

launcher = RayTransformLauncher(FdedupRayTransformConfiguration())

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 01:47:03 INFO - Running locally
# 01:47:03 INFO - fuzzy dedup params are {'doc_column': 'contents', 'id_column': 'int_id_column', 'cluster_column': 'hash_column', 'bucket_cpu': 0.5, 'mhash_cpu': 0.5, 'doc_cpu': 0.5, 'num_doc_actors': 2, 'num_minhash_actors': 1, 'num_bucket_actors': 1, 'num_preprocessors': 2, 'num_permutations': 64, 'threshold': 0.8, 'shingles_size': 5, 'delimiters': ' ', 'snapshot_delay': 1, 'use_bucket_snapshot': False, 'use_doc_snapshot': False, 'random_delay_limit': 10, 'worker_options': {'num_cpus': 1}}
# 01:47:03 INFO - data factory data_ is using local data access: input_folder - output/04_doc_id_out output_folder - output/05_fdedupe_out
# 01:47:03 INFO - data factory data_ max_files -1, n_sample -1
# 01:47:03 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 01:47:03 INFO - pipeline id pipeline_id
# 01:47:03 INFO - code location None
# 01:47:03 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 01:47:03 INFO - actor creation delay 0
# 01:47:03 INFO - job details {'job category': 'preprocessing', 'job name': 'fdedup', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 01:47:05,261	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=260535) 01:47:06 INFO - orchestrator started at 2024-09-06 01:47:06
# (orchestrate pid=260535) 01:47:06 INFO - Number of files is 2, source profile {'max_file_size': 0.008939743041992188, 'min_file_size': 0.008808135986328125, 'total_file_size': 0.017747879028320312}
# (orchestrate pid=260535) 01:47:06 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.407949830405414, 'object_store': 6.203974913805723}
# (orchestrate pid=260535) 01:47:06 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=260535) 01:47:06 INFO - starting run from the beginning
# (orchestrate pid=260535) 01:47:06 INFO - continuing from the very beginning
# (orchestrate pid=260535) 01:47:06 INFO - Fuzzy: num buckets 5, bucket length 11
# (orchestrate pid=260535) 01:47:06 INFO - created 1 bucket actors
# (orchestrate pid=260535) 01:47:06 INFO - created 1 minhash actors
# (orchestrate pid=260535) 01:47:06 INFO - Table preprocessing uses 2 readers
# (orchestrate pid=260535) 01:47:06 INFO - created 2 table processor actors
# (orchestrate pid=260535) 01:47:06 INFO - Completed 0 files (0.0%)  in 4.808108011881511e-06 min. Waiting for completion
# (orchestrate pid=260535) 01:47:08 INFO - Completed processing 2 files in 0.030539087454477944 min
# (orchestrate pid=260535) 01:47:08 INFO - creating minhash snapshots
# (orchestrate pid=260535) 01:47:09 INFO - minhash snapshots created
# (orchestrate pid=260535) 01:47:09 INFO - creating bucket snapshots
# (orchestrate pid=260535) 01:47:10 INFO - bucket snapshots created
# (orchestrate pid=260535) 01:47:10 INFO - created 2 document actors
# (orchestrate pid=260535) 01:47:10 INFO - created 2 bucket processor actors
# (orchestrate pid=260535) 01:47:10 INFO - created bucket processor invoker
# (orchestrate pid=260535) 01:47:10 INFO - added invoker to bucket collectors
# (BucketsHash pid=261366) 01:47:10 INFO - processing buckets 0 long, 25 short
# (BucketsHash pid=261366) 01:47:10 INFO - Done submitting long buckets
# (BucketsHashProcessorInvoker pid=261783) 01:47:10 INFO - Waiting bucket processing completion. Submitted requests 1
# (orchestrate pid=260535) 01:47:10 INFO - Done processing buckets in 0.009708090623219808 min
# (orchestrate pid=260535) 01:47:10 INFO - creating document snapshots
# (orchestrate pid=260535) 01:47:12 INFO - document snapshots created
# (orchestrate pid=260535) 01:47:12 INFO - Completed 0 files (0.0%)  in 1.5521049499511717e-05 min. Waiting for completion
# (orchestrate pid=260535) 01:47:22 INFO - Completed processing 2 files in 0.16247262159983317 min
# (orchestrate pid=260535) 01:47:22 INFO - done flushing in 0.001172780990600586 sec
# 01:47:32 INFO - Completed execution in 0.4856138626734416 min, execution result 0
# ✅ Stage:5 completed successfully
# CPU times: user 189 ms, sys: 184 ms, total: 372 ms
# Wall time: 30.6 s

# %% [markdown]
# ### 7.3 - Inspect Generated output

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)
print ("Duplicate chunks removed  by fuzzy-dedupe:  ", (input_df.shape[0] - output_df.shape[0]))

output_df.head(10)
# Out:
# Input data dimensions (rows x columns)=  (5, 15)
# Output data dimensions (rows x columns)=  (5, 17)
# Duplicate chunks removed  by fuzzy-dedupe:   0
#     filename  num_pages  num_tables  num_doc_elements  \
# 0   mars.pdf          1           0                11
# 1   mars.pdf          1           0                11
# 2  earth.pdf          1           0                11
# 3  earth.pdf          1           0                11
# 4  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 0  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 1  32038943-af7b-43fd-b5e9-c640fdb37c54  pdf
# 2  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 3  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 4  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
#
#                                                 hash  size  \
# 0  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 1  5556be7a44be95d5f40a5235fe1e8774367a070b20eef6...  2505
# 2  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 3  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 4  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
#
#                 date_acquired  pdf_convert_time source_filename  \
# 0  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 1  2024-09-06T01:46:03.416974          1.689363        mars.pdf
# 2  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 3  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 4  2024-09-06T01:46:03.087877          1.674357       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 0  Mars\nMars, the fourth planet from the Sun, is...  $.main-text[5]
# 1  Basic facts about Mars:\n· Distance from the S...  $.main-text[7]
# 2  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 3  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 4  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox  int_id_column  hash_column
# 0            1   [132.86, 500.93, 477.3, 534.53]              4           -1
# 1            1   [147.72, 452.7, 476.98, 474.97]              5           -1
# 2            1  [132.82, 590.31, 478.58, 623.05]              1           -1
# 3            1  [132.89, 512.46, 477.42, 534.47]              2           -1
# 4            1  [147.68, 464.66, 477.03, 487.02]              3           -1

# %% [markdown]
# ## Document Quality - TODO

# %% [markdown]
# ## Step-8:   Text encoding
#
# Encode text for the vector storage.

# %% [markdown]
# ### 8.1 - Set Input/output Folder

# %%
STAGE  += 1
# STAGE  = 7 ## DEBUG

input_folder = output_folder # previous output folder is the input folder for the current stage
output_folder =  os.path.join(MY_CONFIG.OUTPUT_FOLDER, f"{STAGE:02}_encoder_out")

input_df = read_parquet_files_as_df(input_folder)  ## for debug purposes

print (f"🏃🏼 STAGE-{STAGE}: Processing input='{input_folder}' --> output='{output_folder}'")
# Out:
# 🏃🏼 STAGE-6: Processing input='output/05_fdedupe_out' --> output='output/06_encoder_out'

# %% [markdown]
# ### 8.2 - Execute

# %%
# %%time 

from text_encoder_transform_ray import TextEncoderRayTransformConfiguration

local_conf = {
    "input_folder": input_folder,
    "output_folder": output_folder,
}
worker_options = {"num_cpus" : MY_CONFIG.RAY_NUM_CPUS}
params = {
    # where to run
    "run_locally": True,
    # Data access. Only required parameters are specified
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    # orchestrator
    "runtime_worker_options": ParamsUtils.convert_to_ast(worker_options),
    "runtime_num_workers": MY_CONFIG.RAY_RUNTIME_WORKERS,
    # text_encoder
    "text_encoder_model_name": MY_CONFIG.EMBEDDING_MODEL,
}

sys.argv = ParamsUtils.dict_to_req(d=params)
# create launcher
launcher = RayTransformLauncher(TextEncoderRayTransformConfiguration())
# Launch the ray actor(s) to process the input

return_code = launcher.launch()

if return_code == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception ("❌ Ray job failed")
# Out:
# 01:47:34 INFO - Running locally
# 01:47:34 INFO - text_encoder parameters are : {'content_column_name': 'contents', 'output_embeddings_column_name': 'embeddings', 'model_name': 'sentence-transformers/all-MiniLM-L6-v2'}
# 01:47:34 INFO - data factory data_ is using local data access: input_folder - output/05_fdedupe_out output_folder - output/06_encoder_out
# 01:47:34 INFO - data factory data_ max_files -1, n_sample -1
# 01:47:34 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 01:47:34 INFO - pipeline id pipeline_id
# 01:47:34 INFO - code location None
# 01:47:34 INFO - number of workers 2 worker options {'num_cpus': 1, 'max_restarts': -1}
# 01:47:34 INFO - actor creation delay 0
# 01:47:34 INFO - job details {'job category': 'preprocessing', 'job name': 'text_encoder', 'job type': 'ray', 'job id': 'job_id'}
# 2024-09-06 01:47:36,367	INFO worker.py:1744 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=262993) 01:47:39 INFO - orchestrator started at 2024-09-06 01:47:39
# (orchestrate pid=262993) 01:47:39 INFO - Number of files is 2, source profile {'max_file_size': 0.008556365966796875, 'min_file_size': 0.008358955383300781, 'total_file_size': 0.016915321350097656}
# (orchestrate pid=262993) 01:47:39 INFO - Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 12.462906647473574, 'object_store': 6.231453322805464}
# (orchestrate pid=262993) 01:47:39 INFO - Number of workers - 2 with {'num_cpus': 1, 'max_restarts': -1} each
# (orchestrate pid=262993) 01:47:39 INFO - Completed 0 files (0.0%)  in 6.651878356933593e-06 min. Waiting for completion
# (RayTransformFileProcessor pid=263888) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# (RayTransformFileProcessor pid=263888)   warnings.warn(
# (orchestrate pid=262993) 01:47:44 INFO - Completed processing 2 files in 0.07749160528182983 min
# (orchestrate pid=262993) 01:47:44 INFO - done flushing in 0.0009033679962158203 sec
# 01:47:54 INFO - Completed execution in 0.325817608833313 min, execution result 0
# (RayTransformFileProcessor pid=263889) /home/sujee/apps/anaconda3/envs/data-prep-kit-3-py311/lib/python3.11/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# (RayTransformFileProcessor pid=263889)   warnings.warn(
# ✅ Stage:6 completed successfully
# CPU times: user 576 ms, sys: 200 ms, total: 776 ms
# Wall time: 21.3 s

# %% [markdown]
# ### 8.3 - Inspect Generated output
#
# You will see a column called `embeddings` added at the end.  This the text content converted into vectors or embeddings.

# %%
from utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_folder)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.sample(3)
# Out:
# Input data dimensions (rows x columns)=  (5, 17)
# Output data dimensions (rows x columns)=  (5, 18)
#     filename  num_pages  num_tables  num_doc_elements  \
# 3  earth.pdf          1           0                11
# 2  earth.pdf          1           0                11
# 4  earth.pdf          1           0                11
#
#                             document_id  ext  \
# 3  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 2  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
# 4  818d4b3f-f3b7-4453-9c5d-027a72c917bf  pdf
#
#                                                 hash  size  \
# 3  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 2  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
# 4  e88caa778725418ac47c79ef03454451a4ce7839361738...  2383
#
#                 date_acquired  pdf_convert_time source_filename  \
# 3  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 2  2024-09-06T01:46:03.087877          1.674357       earth.pdf
# 4  2024-09-06T01:46:03.087877          1.674357       earth.pdf
#
#                                             contents    doc_jsonpath  \
# 3  Earth\nEarth is the third planet from the Sun....  $.main-text[5]
# 2  Solar System\nOur solar system is a vast and f...  $.main-text[2]
# 4  Earth\n· Distance from the Sun: Average of 149...  $.main-text[7]
#
#    page_number                              bbox  int_id_column  hash_column  \
# 3            1  [132.89, 512.46, 477.42, 534.47]              2           -1
# 2            1  [132.82, 590.31, 478.58, 623.05]              1           -1
# 4            1  [147.68, 464.66, 477.03, 487.02]              3           -1
#
#                                           embeddings
# 3  [0.0724358, -0.058001805, -0.01977186, -0.0243...
# 2  [0.0077404897, -0.020559434, 0.026426662, 0.01...
# 4  [0.06319313, 0.05406263, 0.042939227, 0.002394...

# %% [markdown]
# ## Step-9: Copy output to final output dir

# %%
import shutil

shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER_FINAL, ignore_errors=True)
shutil.copytree(src=output_folder, dst=MY_CONFIG.OUTPUT_FOLDER_FINAL)

print (f"✅ Copied output from '{output_folder}' --> '{MY_CONFIG.OUTPUT_FOLDER_FINAL}'")
# Out:
# ✅ Copied output from 'output/06_encoder_out' --> 'output/output_final'
