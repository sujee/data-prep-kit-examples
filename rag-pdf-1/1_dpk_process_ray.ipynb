# %% [markdown]
# <div style="background-color: #04D7FD; padding: 20px; text-align: left;">
#     <h1 style="color: #000000; font-size: 36px; margin: 0;">Data Processing for RAG with Data Prep Kit (RAY)</h1>
#
# </div>

# %% [markdown]
# ## Before Running the notebook
#
# Please complete [setting up python dev environment](./setup-python-dev-env.md)

# %% [markdown]
# ## Overview
#
# This notebook will process PDF documents as part of RAG pipeline
#
# ![](media/rag-overview-2.png)
#
# This notebook will perform steps 1, 2 and 3 in RAG pipeline.
#
# Here are the processing steps:
#
# Here are the processing steps:
#
# - **pdf2parquet** : Extract text (in markdown format) from PDF and store them as parquet files
# - **Exact Dedup**: Documents with exact content are filtered out
# - **Chunk documents**: Split the PDFs into 'meaningful sections' (paragraphs, sentences ..etc)
# - **Text encoder**: Convert chunks into vectors using embedding models

# %% [markdown]
# ## Step-1: Configuration

# %%
## setup path to utils folder
import sys
sys.path.append('../utils')

# %%
import os
from my_config import MY_CONFIG

## RAY CONFIGURATION
num_cpus_available =  os.cpu_count()
# print (num_cpus_available)
# MY_CONFIG.RAY_NUM_CPUS = num_cpus_available // 2  ## use half the available cores for processing
MY_CONFIG.RAY_NUM_CPUS =  0.5
MY_CONFIG.RAY_MEMORY_GB = 2  # GB
# MY_CONFIG.RAY_RUNTIME_WORKERS = num_cpus_available // 3
MY_CONFIG.RAY_RUNTIME_WORKERS = 2

print (f"Ray configuration: CPUs={MY_CONFIG.RAY_NUM_CPUS},   memory={MY_CONFIG.RAY_MEMORY_GB} GB,  workers={MY_CONFIG.RAY_RUNTIME_WORKERS}")
# Out:
# Ray configuration: CPUs=0.5,   memory=2 GB,  workers=2

# %% [markdown]
# ## Step-2:  Data
#
# We will use white papers  about LLMs.
#
# - [Granite Code Models](https://arxiv.org/abs/2405.04324)
# - [Attention is all you need](https://arxiv.org/abs/1706.03762)
#
# You can of course substite your own data below

# %% [markdown]
# ### 2.1 - Download data

# %%
import os, sys
import shutil
from file_utils import download_file

print ("Using input data:", MY_CONFIG.INPUT_DATA_DIR)
# Out:
# Using input data: ../data/papers

# %%
# import os, sys
# import shutil
# from file_utils import download_file

# shutil.rmtree(MY_CONFIG.INPUT_DATA_DIR, ignore_errors=True)
# shutil.os.makedirs(MY_CONFIG.INPUT_DATA_DIR, exist_ok=True)
# print ("✅ Cleared input directory")
 
# download_file (url = 'https://arxiv.org/pdf/1706.03762', local_file = os.path.join(MY_CONFIG.INPUT_DATA_DIR, 'attention.pdf' ))
# download_file (url = 'https://arxiv.org/pdf/2405.04324', local_file = os.path.join(MY_CONFIG.INPUT_DATA_DIR, 'granite.pdf' ))
# download_file (url = 'https://arxiv.org/pdf/2405.04324', local_file = os.path.join(MY_CONFIG.INPUT_DATA_DIR, 'granite2.pdf' )) # duplicate

# %% [markdown]
# ### 2.2  - Set input/output path variables for the pipeline

# %%
import os, sys
import shutil

if not os.path.exists(MY_CONFIG.INPUT_DATA_DIR ):
    raise Exception (f"❌ Input folder MY_CONFIG.INPUT_DATA_DIR = '{MY_CONFIG.INPUT_DATA_DIR}' not found")

output_parquet_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '01_parquet_out')
output_exact_dedupe_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '02_dedupe_out')
output_chunk_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '03_chunk_out')
output_embeddings_dir = os.path.join (MY_CONFIG.OUTPUT_FOLDER, '04_embeddings_out')


## clear output folder
shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER, ignore_errors=True)
shutil.os.makedirs(MY_CONFIG.OUTPUT_FOLDER, exist_ok=True)

print ("✅ Cleared output directory")
# Out:
# ✅ Cleared output directory

# %% [markdown]
# ## Step-3: pdf2parquet -  Convert data from PDF to Parquet
#
# This step is reading the input folder containing all PDF files and ingest them in a parquet table using the [Docling package](https://github.com/DS4SD/docling).
# The documents are converted into a JSON format which allows to easily chunk it in the later steps.

# %% [markdown]
# ### 3.1 -  Execute

# %%
# %%time 

from dpk_docling2parquet.ray import Docling2Parquet
from data_processing.utils import GB
from dpk_docling2parquet import docling2parquet_contents_types

STAGE = 1 
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{MY_CONFIG.INPUT_DATA_DIR}' --> output='{output_parquet_dir}'\n", flush=True)

result = Docling2Parquet(input_folder= MY_CONFIG.INPUT_DATA_DIR,
                    output_folder= output_parquet_dir, 
                    data_files_to_use=['.pdf'],
                    docling2parquet_contents_type=docling2parquet_contents_types.MARKDOWN,
                    
                    
                    ## runtime options
                    # run_locally= True,
                    # num_cpus= MY_CONFIG.RAY_NUM_CPUS,
                    # memory= MY_CONFIG.RAY_MEMORY_GB * GB,
                    # runtime_num_workers = MY_CONFIG.RAY_RUNTIME_WORKERS,

                    ## debug
                    run_locally= True,
                    num_cpus=  1, 
                    memory= MY_CONFIG.RAY_MEMORY_GB * GB, 
                    runtime_num_workers = 1, ## Note: has to be one for this particular job, to prevent race condition when downloading models!
               ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 2025-11-16 12:52:02,713	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 🏃🏼 STAGE-1: Processing input='../data/papers' --> output='output-papers/01_parquet_out'
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "docling2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <docling2parquet_contents_types.MARKDOWN: 'text/markdown'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <docling2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <docling2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8, 'pipeline': <docling2parquet_pipeline.MULTI_STAGE: 'multi_stage'>, 'generate_picture_images': False, 'generate_page_images': False, 'images_scale': 2.0}"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "pipeline id pipeline_id"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "number of workers 1 worker options {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1}"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "actor creation delay 0"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "job details {'job category': 'preprocessing', 'job name': 'docling2parquet', 'job type': 'ray', 'job id': 'job_id'}"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ max_files -1, n_sample -1"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Data Access:  DataAccessLocal"}
# {"time": "12:52:03", "logger": "dpk", "logLevel": "INFO", "message": "Running locally"}
# 2025-11-16 12:52:05,502	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=3399145) {"time": "12:52:10", "logger": "dpk", "logLevel": "INFO", "message": "orchestrator started at 2025-11-16 12:52:10"}
# (orchestrate pid=3399145) {"time": "12:52:10", "logger": "dpk", "logLevel": "INFO", "message": "Number of files is 3, source profile {'max_file_size': 2.112621307373047, 'min_file_size': 1.2146415710449219, 'total_file_size': 4.541904449462891}"}
# (orchestrate pid=3399145) {"time": "12:52:10", "logger": "dpk", "logLevel": "INFO", "message": "Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 10.341854095458984, 'object_store': 5.170927047729492}"}
# (orchestrate pid=3399145) {"time": "12:52:10", "logger": "dpk", "logLevel": "INFO", "message": "Number of workers - 1 with {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1} each"}
# (RayTransformFileProcessor pid=3400082) {"time": "12:52:15", "logger": "dpk", "logLevel": "INFO", "message": "Initializing models"}
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:15,444 - INFO - Initializing pipeline for StandardPdfPipeline with options hash d6b2c3c6d3d1d554f9b1e86263d8fefd
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:15,455 - INFO - Loading plugin 'docling_defaults'
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:15,455 - INFO - Registered picture descriptions: ['vlm', 'api']
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:15,466 - INFO - Loading plugin 'docling_defaults'
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:15,467 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:15,597 - INFO - Accelerator device: 'cpu'
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:17,192 - INFO - Accelerator device: 'cpu'
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:19,049 - INFO - Accelerator device: 'cpu'
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:20,356 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:20,370 - INFO - Going to convert document batch...
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:52:20,370 - INFO - Processing document attention.pdf
# (orchestrate pid=3399145) {"time": "12:53:20", "logger": "dpk", "logLevel": "INFO", "message": "Completed 1 files in 1.009 min"}
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:53:20,823 - INFO - Finished converting document attention.pdf in 60.47 sec.
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:53:20,878 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:53:20,882 - INFO - Going to convert document batch...
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:53:20,883 - INFO - Processing document granite.pdf
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:57:02,232 - INFO - Finished converting document granite.pdf in 221.35 sec.
# (orchestrate pid=3399145) {"time": "12:57:02", "logger": "dpk", "logLevel": "INFO", "message": "Completed 2 files in 4.699 min"}
# (orchestrate pid=3399145) {"time": "12:57:02", "logger": "dpk", "logLevel": "INFO", "message": "Completed 2 files (66.667%)  in 4.699 min. Waiting for completion"}
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:57:02,304 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:57:02,308 - INFO - Going to convert document batch...
# (RayTransformFileProcessor pid=3400082) 2025-11-16 12:57:02,308 - INFO - Processing document granite2.pdf
# (RayTransformFileProcessor pid=3400082) 2025-11-16 13:00:39,658 - INFO - Finished converting document granite2.pdf in 217.35 sec.
# (orchestrate pid=3399145) {"time": "13:00:39", "logger": "dpk", "logLevel": "INFO", "message": "Completed processing 3 files in 8.323 min"}
# (orchestrate pid=3399145) {"time": "13:00:39", "logger": "dpk", "logLevel": "INFO", "message": "done flushing in 0.001 sec"}
# {"time": "13:00:49", "logger": "dpk", "logLevel": "INFO", "message": "Completed execution in 8.777 min, execution result 0"}
# ✅ Stage:1 completed successfully
# CPU times: user 6.33 s, sys: 1.27 s, total: 7.6 s
# Wall time: 8min 52s

# %% [markdown]
# ### 3.2 - Inspect Generated output
#
# Here we should see one entry per input file processed

# %%
from file_utils import read_parquet_files_as_df

output_df = read_parquet_files_as_df(output_parquet_dir)
# print ("Output dimensions (rows x columns)= ", output_df.shape)
output_df.head(5)
## To display certain columns
#parquet_df[['column1', 'column2', 'column3']].head(5)
# Out:
# Successfully read 3 parquet files with 3 total rows
#         filename                                           contents  \
# 0  attention.pdf  Provided proper attribution is provided, Googl...
# 1   granite2.pdf  ## Granite Code Models: A Family of Open Found...
# 2    granite.pdf  ## Granite Code Models: A Family of Open Found...
#
#    num_pages  num_tables  num_doc_elements  \
# 0         15           4               513
# 1         28          17               484
# 2         28          17               484
#
#                             document_id        document_hash  ext  \
# 0  6d9b3dd6-ec55-4372-bd36-e9502ad03ceb  2949302674760005271  pdf
# 1  4c259929-e3a2-4ac2-9a38-3880a8ff26ca  3127757990743433032  pdf
# 2  1f89c840-f6bc-4560-b8c1-43d5fe297783  3127757990743433032  pdf
#
#                                                 hash    size  \
# 0  214960a61e817387f01087f0b0b323cf1ebd8035fffcab...   48981
# 1  58342470e7d666dca0be87a15fb0552f949a5632606fe1...  121131
# 2  58342470e7d666dca0be87a15fb0552f949a5632606fe1...  121131
#
#                 date_acquired  document_convert_time source_filename
# 0  2025-11-16T12:53:20.869360              60.467835   attention.pdf
# 1  2025-11-16T13:00:39.713942             217.354290    granite2.pdf
# 2  2025-11-16T12:57:02.283422             221.354569     granite.pdf

# %% [markdown]
# ## Step-4: Eliminate Duplicate Documents
#
# We have 2 duplicate documnets here : `granite.pdf` and `granite2.pdf`.
#
# Note how the `hash` for these documents are same.
#
# We are going to perform **de-dupe**
#
# On the content of each document, a SHA256 hash is computed, followed by de-duplication of record having identical hashes.
#
# [Dedupe transform documentation](https://github.com/data-prep-kit/data-prep-kit/blob/dev/transforms/universal/ededup/README.md)

# %% [markdown]
# ### 4.1 - Execute

# %%
# %%time 

from dpk_ededup.ray.transform import Ededup

STAGE = 2
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_parquet_dir}' --> output='{output_exact_dedupe_dir}'\n", flush=True)

result = Ededup(input_folder=output_parquet_dir,
                output_folder=output_exact_dedupe_dir,
                ededup_hash_cpu= 0.5,
                ededup_num_hashes= 2,
                ededup_doc_column="contents",
                ededup_doc_id_column="document_id",
                
                ## runtime options
                run_locally= True,
                num_cpus= MY_CONFIG.RAY_NUM_CPUS,
                memory= MY_CONFIG.RAY_MEMORY_GB * GB,
                runtime_num_workers = MY_CONFIG.RAY_RUNTIME_WORKERS,
    ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 🏃🏼 STAGE-2: Processing input='output-papers/01_parquet_out' --> output='output-papers/02_dedupe_out'
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "exact dedup params are {'doc_column': 'contents', 'doc_id_column': 'document_id', 'use_snapshot': False, 'snapshot_directory': None, 'hash_cpu': 0.5, 'num_hashes': 2}"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "pipeline id pipeline_id"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "number of workers 2 worker options {'num_cpus': 0.5, 'memory': 2147483648, 'max_restarts': -1}"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "actor creation delay 0"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "job details {'job category': 'preprocessing', 'job name': 'ededup', 'job type': 'ray', 'job id': 'job_id'}"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ max_files -1, n_sample -1"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Data Access:  DataAccessLocal"}
# {"time": "13:00:51", "logger": "dpk", "logLevel": "INFO", "message": "Running locally"}
# 2025-11-16 13:00:52,053	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=3403777) {"time": "13:00:57", "logger": "dpk", "logLevel": "INFO", "message": "orchestrator started at 2025-11-16 13:00:57"}
# (orchestrate pid=3403777) {"time": "13:00:57", "logger": "dpk", "logLevel": "INFO", "message": "Number of files is 3, source profile {'max_file_size': 0.04417991638183594, 'min_file_size': 0.020964622497558594, 'total_file_size': 0.10931110382080078}"}
# (orchestrate pid=3403777) {"time": "13:00:57", "logger": "dpk", "logLevel": "INFO", "message": "Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 10.615308380685747, 'object_store': 5.307654189877212}"}
# (orchestrate pid=3403777) {"time": "13:00:57", "logger": "dpk", "logLevel": "INFO", "message": "Number of workers - 2 with {'num_cpus': 0.5, 'memory': 2147483648, 'max_restarts': -1} each"}
# (orchestrate pid=3403777) {"time": "13:01:01", "logger": "dpk", "logLevel": "INFO", "message": "Completed 1 files in 0.0 min"}
# (orchestrate pid=3403777) {"time": "13:01:01", "logger": "dpk", "logLevel": "INFO", "message": "Completed 1 files (33.333%)  in 0.0 min. Waiting for completion"}
# (orchestrate pid=3403777) {"time": "13:01:01", "logger": "dpk", "logLevel": "INFO", "message": "Completed processing 3 files in 0.001 min"}
# (orchestrate pid=3403777) {"time": "13:01:01", "logger": "dpk", "logLevel": "INFO", "message": "done flushing in 0.001 sec"}
# {"time": "13:01:11", "logger": "dpk", "logLevel": "INFO", "message": "Completed execution in 0.336 min, execution result 0"}
# ✅ Stage:2 completed successfully
# CPU times: user 148 ms, sys: 165 ms, total: 313 ms
# Wall time: 21.7 s

# %% [markdown]
# ### 4.2 - Inspect Generated output
#
# We would see 2 documents: `attention.pdf`  and `granite.pdf`.  The duplicate `granite.pdf` has been filtered out!

# %%
from file_utils import read_parquet_files_as_df

input_df = read_parquet_files_as_df(output_parquet_dir)
output_df = read_parquet_files_as_df(output_exact_dedupe_dir)

# print ("Input data dimensions (rows x columns)= ", input_df.shape)
# print ("Output data dimensions (rows x columns)= ", output_df.shape)
print (f"Input files before exact dedupe : {input_df.shape[0]:,}")
print (f"Output files after exact dedupe : {output_df.shape[0]:,}")
print ("Duplicate files removed :  ", (input_df.shape[0] - output_df.shape[0]))

output_df.sample(min(3, output_df.shape[0]))
# Out:
# Successfully read 3 parquet files with 3 total rows
# Successfully read 2 parquet files with 2 total rows
# Input files before exact dedupe : 3
# Output files after exact dedupe : 2
# Duplicate files removed :   1
#         filename                                           contents  \
# 1    granite.pdf  ## Granite Code Models: A Family of Open Found...
# 0  attention.pdf  Provided proper attribution is provided, Googl...
#
#    num_pages  num_tables  num_doc_elements  \
# 1         28          17               484
# 0         15           4               513
#
#                             document_id        document_hash  ext  \
# 1  1f89c840-f6bc-4560-b8c1-43d5fe297783  3127757990743433032  pdf
# 0  6d9b3dd6-ec55-4372-bd36-e9502ad03ceb  2949302674760005271  pdf
#
#                                                 hash    size  \
# 1  58342470e7d666dca0be87a15fb0552f949a5632606fe1...  121131
# 0  214960a61e817387f01087f0b0b323cf1ebd8035fffcab...   48981
#
#                 date_acquired  document_convert_time source_filename
# 1  2025-11-16T12:57:02.283422             221.354569     granite.pdf
# 0  2025-11-16T12:53:20.869360              60.467835   attention.pdf

# %% [markdown]
# ##  Step-5: Doc chunks
#
# Split the documents in chunks.
#
# [Chunking transform documentation](https://github.com/data-prep-kit/data-prep-kit/blob/dev/transforms/language/doc_chunk/README.md)
#
# **Experiment with chunking size to find the setting that works best for your documents**

# %% [markdown]
# ### 5.1 -  Execute

# %%
# %%time

from dpk_doc_chunk.ray.transform import DocChunk
from data_processing.utils import GB

STAGE = 3
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_exact_dedupe_dir}' --> output='{output_chunk_dir}'\n", flush=True)

result = DocChunk(input_folder=output_exact_dedupe_dir,
                        output_folder=output_chunk_dir,
                        doc_chunk_chunking_type= "li_markdown",

                        ## runtime options
                        run_locally= True,
                        num_cpus= MY_CONFIG.RAY_NUM_CPUS,
                        memory= MY_CONFIG.RAY_MEMORY_GB * GB,
                        runtime_num_workers = MY_CONFIG.RAY_RUNTIME_WORKERS,
                        ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 🏃🏼 STAGE-3: Processing input='output-papers/02_dedupe_out' --> output='output-papers/03_chunk_out'
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "doc_chunk parameters are : {'chunking_type': 'li_markdown', 'content_column_name': 'contents', 'doc_id_column_name': 'document_id', 'output_chunk_column_name': 'contents', 'output_source_doc_id_column_name': 'source_document_id', 'output_jsonpath_column_name': 'doc_jsonpath', 'output_pageno_column_name': 'page_number', 'output_bbox_column_name': 'bbox', 'chunk_size_tokens': 128, 'chunk_overlap_tokens': 30, 'dl_min_chunk_len': None}"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "pipeline id pipeline_id"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "number of workers 2 worker options {'num_cpus': 0.5, 'memory': 2147483648, 'max_restarts': -1}"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "actor creation delay 0"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "job details {'job category': 'preprocessing', 'job name': 'doc_chunk', 'job type': 'ray', 'job id': 'job_id'}"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ max_files -1, n_sample -1"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Data Access:  DataAccessLocal"}
# {"time": "13:01:13", "logger": "dpk", "logLevel": "INFO", "message": "Running locally"}
# 2025-11-16 13:01:14,506	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=3405344) {"time": "13:01:19", "logger": "dpk", "logLevel": "INFO", "message": "orchestrator started at 2025-11-16 13:01:19"}
# (orchestrate pid=3405344) {"time": "13:01:19", "logger": "dpk", "logLevel": "INFO", "message": "Number of files is 3, source profile {'max_file_size': 0.04416656494140625, 'min_file_size': 0.0028314590454101562, 'total_file_size': 0.067962646484375}"}
# (orchestrate pid=3405344) {"time": "13:01:19", "logger": "dpk", "logLevel": "INFO", "message": "Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 10.60159835871309, 'object_store': 5.300799178890884}"}
# (orchestrate pid=3405344) {"time": "13:01:19", "logger": "dpk", "logLevel": "INFO", "message": "Number of workers - 2 with {'num_cpus': 0.5, 'memory': 2147483648, 'max_restarts': -1} each"}
# (orchestrate pid=3405344) {"time": "13:01:24", "logger": "dpk", "logLevel": "INFO", "message": "Completed 1 files in 0.0 min"}
# (orchestrate pid=3405344) {"time": "13:01:24", "logger": "dpk", "logLevel": "INFO", "message": "Completed 1 files (33.333%)  in 0.0 min. Waiting for completion"}
# (orchestrate pid=3405344) {"time": "13:01:24", "logger": "dpk", "logLevel": "INFO", "message": "Completed processing 3 files in 0.0 min"}
# (orchestrate pid=3405344) {"time": "13:01:24", "logger": "dpk", "logLevel": "INFO", "message": "done flushing in 0.001 sec"}
# (RayTransformFileProcessor pid=3406319) {"time": "13:01:24", "logger": "dpk", "logLevel": "WARNING", "message": "table is empty, skipping processing"}
# {"time": "13:01:34", "logger": "dpk", "logLevel": "INFO", "message": "Completed execution in 0.355 min, execution result 0"}
# ✅ Stage:3 completed successfully
# CPU times: user 661 ms, sys: 262 ms, total: 923 ms
# Wall time: 23.3 s

# %% [markdown]
# ### 5.2 - Inspect Generated output
#
# We would see documents are split into many chunks

# %%
from file_utils import read_parquet_files_as_df

input_df = read_parquet_files_as_df(output_exact_dedupe_dir)  ## for debug purposes
output_df = read_parquet_files_as_df(output_chunk_dir)

print (f"Files processed : {input_df.shape[0]:,}")
print (f"Chunks created : {output_df.shape[0]:,}")

# print ("Input data dimensions (rows x columns)= ", input_df.shape)
# print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.sample(min(3, output_df.shape[0]))
# Out:
# Successfully read 2 parquet files with 2 total rows
# Successfully read 2 parquet files with 61 total rows
# Files processed : 2
# Chunks created : 61
#          filename  num_pages  num_tables  num_doc_elements  \
# 33    granite.pdf         28          17               484
# 12  attention.pdf         15           4               513
# 24  attention.pdf         15           4               513
#
#           document_hash  ext  \
# 33  3127757990743433032  pdf
# 12  2949302674760005271  pdf
# 24  2949302674760005271  pdf
#
#                                                  hash    size  \
# 33  58342470e7d666dca0be87a15fb0552f949a5632606fe1...  121131
# 12  214960a61e817387f01087f0b0b323cf1ebd8035fffcab...   48981
# 24  214960a61e817387f01087f0b0b323cf1ebd8035fffcab...   48981
#
#                  date_acquired  document_convert_time source_filename  \
# 33  2025-11-16T12:57:02.283422             221.354569     granite.pdf
# 12  2025-11-16T12:53:20.869360              60.467835   attention.pdf
# 24  2025-11-16T12:53:20.869360              60.467835   attention.pdf
#
#                       source_document_id  \
# 33  1f89c840-f6bc-4560-b8c1-43d5fe297783
# 12  6d9b3dd6-ec55-4372-bd36-e9502ad03ceb
# 24  6d9b3dd6-ec55-4372-bd36-e9502ad03ceb
#
#                                              contents  \
# 33  ## 2.2 Exact and Fuzzy Deduplication\n\nWeadop...
# 12  ## 3.3 Position-wise Feed-Forward Networks\n\n...
# 24  ## 6.3 English Constituency Parsing\n\nTo eval...
#
#                                           document_id
# 33  ea0e99c1a018e0ec8dd5ea8aceb222c889d510acdd7313...
# 12  1a97c9bc3e8cb8908b65d45262e35f4518dfec9ba91f7d...
# 24  96797312c2020f4406609dc6d30585c50c669d5e4cc1d3...

# %% [markdown]
# ## Step-6:   Calculate Embeddings for Chunks
#
# we will calculate embeddings for each chunk using an open source embedding model
#
# [Embeddings / Text Encoder documentation](https://github.com/data-prep-kit/data-prep-kit/blob/dev/transforms/language/text_encoder/README.md)

# %% [markdown]
# ### 6.1 - Execute

# %%
# %%time 

from dpk_text_encoder.ray.transform import TextEncoder
from data_processing.utils import GB

STAGE  = 4
print (f"🏃🏼 STAGE-{STAGE}: Processing input='{output_chunk_dir}' --> output='{output_embeddings_dir}'\n", flush=True)

result = TextEncoder(input_folder= output_chunk_dir, 
               output_folder= output_embeddings_dir, 
               text_encoder_model_name = MY_CONFIG.EMBEDDING_MODEL,
               
               ## runtime options
               run_locally= True,
               num_cpus= MY_CONFIG.RAY_NUM_CPUS,
               memory= MY_CONFIG.RAY_MEMORY_GB * GB,
               runtime_num_workers = MY_CONFIG.RAY_RUNTIME_WORKERS,
               ).transform()

if result == 0:
    print (f"✅ Stage:{STAGE} completed successfully")
else:
    raise Exception (f"❌ Stage:{STAGE}  failed")
# Out:
# 🏃🏼 STAGE-4: Processing input='output-papers/03_chunk_out' --> output='output-papers/04_embeddings_out'
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "text_encoder parameters are : {'content_column_name': 'contents', 'output_embeddings_column_name': 'embeddings', 'model_name': 'sentence-transformers/all-MiniLM-L6-v2'}"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "pipeline id pipeline_id"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "number of workers 2 worker options {'num_cpus': 0.5, 'memory': 2147483648, 'max_restarts': -1}"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "actor creation delay 0"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "job details {'job category': 'preprocessing', 'job name': 'text_encoder', 'job type': 'ray', 'job id': 'job_id'}"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ max_files -1, n_sample -1"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Data Access:  DataAccessLocal"}
# {"time": "13:01:36", "logger": "dpk", "logLevel": "INFO", "message": "Running locally"}
# 2025-11-16 13:01:37,260	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# (orchestrate pid=3406855) {"time": "13:01:41", "logger": "dpk", "logLevel": "INFO", "message": "orchestrator started at 2025-11-16 13:01:41"}
# (orchestrate pid=3406855) {"time": "13:01:41", "logger": "dpk", "logLevel": "INFO", "message": "Number of files is 2, source profile {'max_file_size': 0.046176910400390625, 'min_file_size': 0.02873516082763672, 'total_file_size': 0.07491207122802734}"}
# (orchestrate pid=3406855) {"time": "13:01:41", "logger": "dpk", "logLevel": "INFO", "message": "Cluster resources: {'cpus': 16, 'gpus': 1, 'memory': 10.579920960590243, 'object_store': 5.289960479363799}"}
# (orchestrate pid=3406855) {"time": "13:01:41", "logger": "dpk", "logLevel": "INFO", "message": "Number of workers - 2 with {'num_cpus': 0.5, 'memory': 2147483648, 'max_restarts': -1} each"}
# (orchestrate pid=3406855) {"time": "13:01:49", "logger": "dpk", "logLevel": "INFO", "message": "Completed 0 files (0.0%)  in 0.0 min. Waiting for completion"}
# (orchestrate pid=3406855) {"time": "13:01:51", "logger": "dpk", "logLevel": "INFO", "message": "Completed processing 2 files in 0.034 min"}
# (orchestrate pid=3406855) {"time": "13:01:51", "logger": "dpk", "logLevel": "INFO", "message": "done flushing in 0.001 sec"}
# {"time": "13:02:01", "logger": "dpk", "logLevel": "INFO", "message": "Completed execution in 0.417 min, execution result 0"}
# ✅ Stage:4 completed successfully
# CPU times: user 224 ms, sys: 182 ms, total: 407 ms
# Wall time: 26.6 s

# %% [markdown]
# ### 6.2 - Inspect Generated output

# %%
from file_utils import read_parquet_files_as_df

input_df = read_parquet_files_as_df(output_chunk_dir)
output_df = read_parquet_files_as_df(output_embeddings_dir)

print ("Input data dimensions (rows x columns)= ", input_df.shape)
print ("Output data dimensions (rows x columns)= ", output_df.shape)

output_df.sample(min(3, output_df.shape[0]))
# Out:
# Successfully read 2 parquet files with 61 total rows
# Successfully read 2 parquet files with 61 total rows
# Input data dimensions (rows x columns)=  (61, 14)
# Output data dimensions (rows x columns)=  (61, 15)
#          filename  num_pages  num_tables  num_doc_elements  \
# 4   attention.pdf         15           4               513
# 22  attention.pdf         15           4               513
# 56    granite.pdf         28          17               484
#
#           document_hash  ext  \
# 4   2949302674760005271  pdf
# 22  2949302674760005271  pdf
# 56  3127757990743433032  pdf
#
#                                                  hash    size  \
# 4   214960a61e817387f01087f0b0b323cf1ebd8035fffcab...   48981
# 22  214960a61e817387f01087f0b0b323cf1ebd8035fffcab...   48981
# 56  58342470e7d666dca0be87a15fb0552f949a5632606fe1...  121131
#
#                  date_acquired  document_convert_time source_filename  \
# 4   2025-11-16T12:53:20.869360              60.467835   attention.pdf
# 22  2025-11-16T12:53:20.869360              60.467835   attention.pdf
# 56  2025-11-16T12:57:02.283422             221.354569     granite.pdf
#
#                       source_document_id  \
# 4   6d9b3dd6-ec55-4372-bd36-e9502ad03ceb
# 22  6d9b3dd6-ec55-4372-bd36-e9502ad03ceb
# 56  1f89c840-f6bc-4560-b8c1-43d5fe297783
#
#                                              contents  \
# 4   ## 2 Background\n\nThe goal of reducing sequen...
# 22  ## 6.1 Machine Translation\n\nOn the WMT 2014 ...
# 56  ## 6.7 Model Robustness\n\nWhile the performan...
#
#                                           document_id  \
# 4   84e98ea1b539c14df1e2219a455074552f0339ede803b6...
# 22  5747e89ea00329843a874f8a3f0c2055469ded849066d1...
# 56  bac7e00148c7ab245583902ca33f6489228e82f4758791...
#
#                                            embeddings
# 4   [-0.082636066, -0.037095945, 0.013174194, -0.0...
# 22  [-0.0403513, -0.071009785, 0.0003329234, 0.013...
# 56  [-0.08713458, -0.06469581, -0.020314984, 0.035...

# %% [markdown]
# ## Step-7: Copy output to final output dir

# %%
import shutil

shutil.rmtree(MY_CONFIG.OUTPUT_FOLDER_FINAL, ignore_errors=True)
shutil.copytree(src=output_embeddings_dir, dst=MY_CONFIG.OUTPUT_FOLDER_FINAL)

print (f"✅ Copied output from '{output_embeddings_dir}' --> '{MY_CONFIG.OUTPUT_FOLDER_FINAL}'")
# Out:
# ✅ Copied output from 'output-papers/04_embeddings_out' --> 'output-papers/output_final'
